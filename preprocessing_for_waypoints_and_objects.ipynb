# %%
import pandas as pd
import numpy as np
import re
import os

# %%
# Function to process the String to correct format - removing unwanted characters
def parse_objects_data_preprocessing(parsed_object, target):
    if parsed_object.startswith('['):
        parsed_object = parsed_object[1:]
    if (target == 'objects' and parsed_object.endswith(']]')) or (target == 'waypoints' and parsed_object.endswith(']')):
        parsed_object = parsed_object[:-1]
    return parsed_object.strip()

# %%
# Function to parse Strings to correct types
def parse_value(value):
    value = value.strip()
    if re.match(r'^\d+$', value):  # Integer
        return int(value)
    elif re.match(r'^\d+\.\d+$', value):  # Float
        return float(value)
    elif value in ['True', 'False']:  # Boolean
        return value == 'True'
    return value.strip('"')  # String

# %%
# Function to recursively parse the lines of tab-separated key-value pairs into a nested dictionary
def recursive_parse(lines, level=0):
    obj = {}
    
    while lines:
        line = lines.pop(0)
        tabs = len(re.match(r'^\t*', line).group())
        
        # If the indentation level decreases, stop processing
        if tabs < level:
            lines.insert(0, line)
            break
        
        parts = line.strip().split(":", 1)
        key = parts[0].strip()
        value = parts[1].strip() if len(parts) > 1 else ""
        
        if not value:  # If value is empty, treat as nested object
            obj[key] = recursive_parse(lines, level=tabs + 1)
        else:  # Parse key-value pair
            parsed_value = parse_value(value)
            obj[key] = parsed_value
    
    return obj

# %%
# Function to parse the String value into separate objects
def parse_objects_column(objects_data):
    # Values are separated by commas
    objects_raw = objects_data.split(",")
    parsed_objects = []

    for obj_data in objects_raw:
        # Formatting data by replacing spaces with tabs
        formatted_data = re.sub(r' {4}', '\t\t', obj_data.strip())
        formatted_data = re.sub(r' {2}', '\t', formatted_data)
        lines = formatted_data.splitlines()
        parsed_object = recursive_parse(lines)
        parsed_objects.append(parsed_object)
    
    return parsed_objects

# %%
def process_csv(file_path, target, desired_features, output_path):
        
        df = pd.read_csv(file_path)

        expanded_rows = []

        for _, row in df.iterrows():
            # Preprocess the target column (either 'objects' or 'waypoints')
            target_raw = parse_objects_data_preprocessing(row[target], target)

            try:
                # Parse the nested data
                parsed_objects = parse_objects_column(target_raw)

                if not isinstance(parsed_objects, list):
                    parsed_objects = [parsed_objects]

                # Create a new row for the parsed objects
                new_row = row.drop(labels=[target]).to_dict()

                # Finding the desired features and creating new columns for each object, based on the index
                for i, obj in enumerate(parsed_objects):
                    for feature, json_path in desired_features.items():
                        keys = json_path.split('.')
                        value = obj
                        for key in keys:
                            value = value.get(key, None) if isinstance(value, dict) else None
                        new_row[f"{feature}_{i+1}"] = value

                expanded_rows.append(new_row)

            except Exception as e:
                print(f"Error parsing row in {file_path}: {e}")
                continue

        # Create a new DataFrame
        expanded_df = pd.DataFrame(expanded_rows)

        # Add missing columns for uniformity (if there are fewer objects than the maximum)
        max_objects = max(
            sum(1 for col in expanded_df.columns if col.startswith(feature))
            for feature in desired_features.keys()
        )
        for feature in desired_features.keys():
            for i in range(1, max_objects + 1):
                column_name = f"{feature}_{i}"
                if column_name not in expanded_df.columns:
                    expanded_df[column_name] = np.nan

        # Save to output file
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        expanded_df.to_csv(output_path, index=False)
        print(f"Processed CSV saved to {output_path}")

# %%
# Defining the target column for each file type
targets = {
    'detection-final_objects.csv': 'objects',
    'planning-global_path.csv': 'waypoints',
    'planning-local_path.csv': 'waypoints'
}

# %%
# Defining the desired features for each target type
desired_features_mapping = {
    'objects': {
        'label': 'label',
        'position_x': 'pose.position.x',
        'position_y': 'pose.position.y',
        'position_z': 'pose.position.z',
        'orientation_x': 'pose.orientation.x',
        'orientation_y': 'pose.orientation.y',
        'orientation_z': 'pose.orientation.z',
        'orientation_w': 'pose.orientation.w',
        'dimensions_x': 'dimensions.x',
        'dimensions_y': 'dimensions.y',
        'dimensions_z': 'dimensions.z',
    },
    'waypoints': {
        'position_x': 'pose.pose.position.x',
        'position_y': 'pose.pose.position.y',
        'position_z': 'pose.pose.position.z',
        'orientation_x': 'pose.pose.orientation.x',
        'orientation_y': 'pose.pose.orientation.y',
        'orientation_z': 'pose.pose.orientation.z',
        'orientation_w': 'pose.pose.orientation.w',
        'twist_linear_x': 'twist.twist.linear.x',
        'twist_linear_y': 'twist.twist.linear.y',
        'twist_linear_z': 'twist.twist.linear.z',
        'twist_angular_x': 'twist.twist.angular.x',
        'twist_angular_y': 'twist.twist.angular.y',
        'twist_angular_z': 'twist.twist.angular.z',
        'dtlane_lw': 'dtlane.lw',
        'dtlane_rw': 'dtlane.rw'
    }
}

# %%
# Defining folders we want to process
input_folders = [
    'F:\\2023-10-16-10-14-49_tiksoja_ride_02_sfa',
    'F:\\2023-10-16-10-30-17_tiksoja_ride_03_cluster',
    'F:\\2023-10-16-10-50-24_tiksoja_ride_04_sfa',
    'F:\\2023-10-16-13-47-19_tiksoja_ride_05_cluster',
    'F:\\2023-10-16-15-23-20_tiksoja_ride_08_cluster',
    'F:\\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2',
    'F:\\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1',
    'F:\\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2',
    'F:\\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1',
    'F:\\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2',
    'F:\\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1',
    'F:\\2023-10-30-15-04-36_tiksoja_ride_13_cluster_split_1',
    'F:\\2023-10-30-15-19-32_tiksoja_ride_13_cluster_split_2',
    'F:\\2023-10-31-09-57-58_tiksoja_ride_14_sfa_split_1',
    'F:\\2023-10-31-10-17-12_tiksoja_ride_14_sfa_split_2',
    'F:\\2023-10-31-10-41-16_tiksoja_ride_15_cluster_split_1',
    'F:\\2023-10-31-10-59-27_tiksoja_ride_15_cluster_split_2',
    'F:\\2023-11-02-11-47-11_tiksoja_ride_16_sfa_split_1',
    'F:\\2023-11-02-12-00-24_tiksoja_ride_16_sfa_split_2',
    'F:\\2023-11-02-12-44-53_tiksoja_ride_17_cluster_split_1',
    'F:\\2023-11-02-12-58-32_tiksoja_ride_17_cluster_split_2',
    'F:\\2023-11-03-09-57-03_tiksoja_ride_18_sfa_split_1',
    'F:\\2023-11-03-10-21-22_tiksoja_ride_18_sfa_split_2',
    'F:\\2023-11-03-10-59-56_tiksoja_ride_19_cluster_split_1',
    'F:\\2023-11-03-11-14-53_tiksoja_ride_19_cluster_split_2',
    'F:\\2023-11-03-13-42-01_tiksoja_ride_20_sfa_split_1',
    'F:\\2023-11-03-13-56-06_tiksoja_ride_20_sfa_split_2'
]

# %%
# Defingin the files we want to process
file_list = [
    'detection-final_objects.csv',
    'planning-global_path.csv',
    'planning-local_path.csv'
]

# %%
# Destination folder for processed CSVs
output_folder = "F:\\Processed_CSVs"

# %%
# Iterating over the folders and files and creating processed CSVs
for folder in input_folders:
    for file_name in file_list:
        file_path = os.path.join(folder, file_name)
        if os.path.exists(file_path):
            # The target based on the file name
            target = targets[file_name]
            # Desired features based on the target
            desired_features = desired_features_mapping[target]
            output_path = os.path.join(output_folder, os.path.basename(folder), f"processed_{file_name}")
            process_csv(file_path, target, desired_features, output_path)
        else:
            print(f"File not found: {file_path}")
# Out:
# F:\2023-10-16-10-14-49_tiksoja_ride_02_sfa\detection-final_objects.csv
# Processed CSV saved to F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_detection-final_objects.csv
# F:\2023-10-16-10-14-49_tiksoja_ride_02_sfa\planning-global_path.csv
# Processed CSV saved to F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_planning-global_path.csv
# F:\2023-10-16-10-14-49_tiksoja_ride_02_sfa\planning-local_path.csv
# Processed CSV saved to F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_planning-local_path.csv

# %%
import os
import pandas as pd
from collections import defaultdict

# Define the root directory containing the folders
root_directory = "F:\\Processed_CSVs"

# Initialize a dictionary to store the column count overview
column_count_overview = {
    "File 1": defaultdict(int),
    "File 2": defaultdict(int),
    "File 3": defaultdict(int),
}

# Iterate over all folders in the root directory
for folder_name in os.listdir(root_directory):
    folder_path = os.path.join(root_directory, folder_name)
    if not os.path.isdir(folder_path):
        continue

    # Iterate over all files in the folder (assume fixed order File 1, File 2, File 3)
    for i, file_name in enumerate(sorted(os.listdir(folder_path))):
        file_path = os.path.join(folder_path, file_name)

        try:
            # Read the CSV file
            df = pd.read_csv(file_path, low_memory=False)

            # Get the last column name and extract the number from the format {feature}_{i}
            last_column = df.columns[-1]
            try:
                column_index = int(last_column.split("_")[-1])
                column_count_overview[f"File {i + 1}"][column_index] += 1
            except ValueError:
                print(f"Invalid format for the last column in {file_path}: {last_column}")

        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
# Out:
# File 1: {27: 1, 192: 1, 13: 1, 201: 1, 196: 1, 33: 1, 208: 2, 207: 1, 199: 2, 43: 1, 179: 1, 200: 1, 28: 1, 49: 1, 197: 1, 330: 1, 34: 1, 44: 1, 206: 1, 202: 1, 42: 2, 45: 1, 190: 1, 24: 1}
# File 2: {670: 3, 585: 2, 645: 1, 315: 1, 817: 1, 765: 1, 686: 1, 661: 1, 763: 3, 909: 1, 1082: 1, 1191: 1, 925: 1, 1085: 1, 646: 1, 667: 1, 741: 2, 1228: 1, 1309: 1, 908: 1, 635: 1}
# File 3: {100: 27}

# %%
# Print the summary overview with the minimum key
for file_type, counts in column_count_overview.items():
    counts_dict = dict(counts)
    min_key = min(counts_dict.keys()) if counts_dict else None
    print(f"{file_type}: {counts_dict}, Minimum key: {min_key}")
# Out:
# File 1: {27: 1, 192: 1, 13: 1, 201: 1, 196: 1, 33: 1, 208: 2, 207: 1, 199: 2, 43: 1, 179: 1, 200: 1, 28: 1, 49: 1, 197: 1, 330: 1, 34: 1, 44: 1, 206: 1, 202: 1, 42: 2, 45: 1, 190: 1, 24: 1}, Minimum key: 13
# File 2: {670: 3, 585: 2, 645: 1, 315: 1, 817: 1, 765: 1, 686: 1, 661: 1, 763: 3, 909: 1, 1082: 1, 1191: 1, 925: 1, 1085: 1, 646: 1, 667: 1, 741: 2, 1228: 1, 1309: 1, 908: 1, 635: 1}, Minimum key: 315
# File 3: {100: 27}, Minimum key: 100

# %%
import os
import pandas as pd
from collections import defaultdict

# Define the input folder
processed_folder = "F:\\Processed_CSVs"

# Initialize a dictionary to store results
filled_columns_overview = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))

# Dictionary to track overall minimums for each file type
overall_minimums = defaultdict(lambda: float('inf'))

# Process each folder
for folder in os.listdir(processed_folder):
    folder_path = os.path.join(processed_folder, folder)
    if os.path.isdir(folder_path):
        for idx, file_name in enumerate(sorted(os.listdir(folder_path))):  # Ensure consistent file order
            file_path = os.path.join(folder_path, file_name)
            if file_name.endswith(".csv"):
                try:
                    # Read the file
                    df = pd.read_csv(file_path, low_memory=False)

                    # Initialize a dictionary for filled column counts in this file
                    filled_columns_count = defaultdict(int)

                    for _, row in df.iterrows():
                        # Find the last non-NaN value's column
                        last_filled = row.last_valid_index()

                        if last_filled:
                            # Extract the last column index {feature}_{i}
                            if "_" in last_filled:
                                i = last_filled.split("_")[-1]  # Get the last part after the last underscore
                                if i.isdigit():  # Ensure it's a number
                                    filled_columns_count[int(i)] += 1
                                #else:
                                    #filled_columns_count[0] += 1  # Add key 0 for rows with no valid numbers
                            #else:
                                #filled_columns_count[0] += 1  # Add key 0 for rows with no underscore
                        #else:
                            #filled_columns_count[0] += 1  # Add key 0 for completely empty rows

                    # Save results for the current file
                    filled_columns_overview[folder][f"File {idx + 1}"] = dict(filled_columns_count)

                    # Update overall minimum for this file type
                    if filled_columns_count:
                        file_min = min(filled_columns_count.keys())
                        overall_minimums[f"File {idx + 1}"] = min(overall_minimums[f"File {idx + 1}"], file_min)

                except Exception as e:
                    print(f"Error processing {file_path}: {e}")

# Print results
for folder, files in filled_columns_overview.items():
    print(f"Folder: {folder}")
    for file, counts in files.items():
        file_min = min(counts.keys()) if counts else None
        print(f"  {file}: {counts} (Minimum: {file_min})")

print("\nOverall Minimums Across All Folders:")
for file_type, min_value in overall_minimums.items():
    print(f"  {file_type}: {min_value}")
# Out:
# Folder: 2023-10-16-10-14-49_tiksoja_ride_02_sfa
#   File 1: {9: 128, 11: 102, 12: 79, 10: 137, 13: 76, 15: 76, 16: 91, 14: 80, 17: 141, 18: 156, 20: 85, 21: 70, 19: 129, 24: 34, 26: 13, 25: 19, 23: 25, 22: 37, 27: 9, 7: 135, 8: 119, 6: 229, 4: 400, 5: 319, 3: 650, 2: 822, 1: 1345} (Minimum: 1)
#   File 2: {77: 1, 670: 1} (Minimum: 77)
#   File 3: {99: 4, 98: 2, 97: 2, 96: 4, 95: 2, 94: 3, 93: 3, 92: 2, 91: 3, 90: 4, 89: 2, 88: 3, 87: 4, 86: 3, 85: 4, 84: 4, 83: 4, 82: 4, 81: 5, 80: 5, 79: 6, 78: 6, 77: 7, 76: 9, 75: 10, 74: 69, 73: 9, 72: 5, 71: 6, 70: 4, 69: 3, 68: 5, 67: 3, 66: 3, 65: 4, 64: 4, 63: 3, 62: 3, 61: 4, 60: 3, 59: 4, 58: 4, 57: 3, 56: 3, 55: 4, 54: 4, 53: 3, 52: 5, 51: 4, 50: 3, 49: 5, 48: 4, 47: 4, 46: 5, 45: 4, 44: 4, 43: 5, 42: 4, 41: 5, 40: 3, 39: 4, 38: 5, 37: 5, 36: 4, 35: 5, 34: 4, 33: 4, 32: 5, 31: 4, 30: 5, 29: 4, 28: 5, 27: 5, 26: 5, 25: 4, 24: 5, 23: 5, 22: 5, 21: 5, 20: 5, 19: 5, 18: 6, 17: 4, 16: 5, 15: 6, 14: 4, 13: 6, 12: 6, 11: 6, 10: 7, 9: 7, 8: 9, 7: 11, 6: 16, 100: 7487} (Minimum: 6)
# Folder: 2023-10-16-10-30-17_tiksoja_ride_03_cluster
#   File 1: {171: 10, 176: 7, 178: 8, 183: 4, 172: 9, 167: 5, 181: 4, 165: 8, 163: 11, 175: 6, 180: 10, 170: 5, 166: 12, 169: 6, 173: 4, 182: 5, 174: 5, 190: 2, 177: 2, 162: 7, 161: 3, 164: 7, 159: 19, 168: 3, 156: 7, 160: 7, 155: 10, 134: 24, 141: 21, 137: 25, 140: 25, 135: 24, 132: 23, 133: 19, 144: 10, 151: 10, 158: 3, 149: 11, 147: 11, 145: 11, 142: 25, 146: 18, 153: 8, 138: 28, 127: 17, 124: 21, 128: 25, 139: 23, 117: 31, 118: 20, 120: 24, 119: 26, 114: 30, 121: 26, 123: 22, 122: 17, 131: 21, 129: 16, 143: 27, 136: 26, 150: 6, 126: 24, 148: 7, 116: 25, 113: 29, 111: 40, 105: 59, 107: 41, 106: 50, 112: 39, 115: 31, 98: 44, 92: 57, 96: 56, 95: 58, 97: 59, 93: 64, 90: 56, 103: 49, 100: 53, 94: 54, 91: 53, 83: 58, 82: 60, 78: 69, 81: 66, 84: 55, 77: 70, 74: 52, 73: 54, 72: 59, 67: 52, 70: 47, 79: 70, 76: 51, 85: 63, 88: 71, 89: 68, 87: 54, 99: 52, 104: 52, 71: 65, 58: 42, 57: 46, 61: 45, 63: 53, 59: 36, 64: 56, 62: 46, 65: 72, 53: 43, 60: 43, 55: 44, 69: 61, 52: 41, 49: 43, 68: 53, 80: 48, 75: 53, 66: 73, 51: 41, 48: 49, 50: 46, 45: 47, 54: 34, 47: 32, 56: 36, 43: 37, 40: 47, 41: 36, 39: 35, 37: 33, 35: 46, 32: 52, 28: 58, 29: 52, 25: 47, 23: 35, 31: 53, 30: 53, 27: 50, 26: 47, 24: 32, 21: 24, 20: 24, 18: 13, 15: 13, 16: 5, 14: 5, 13: 1, 9: 3, 8: 7, 5: 6, 4: 23, 3: 31, 2: 71, 1: 186, 6: 6, 7: 6, 17: 4, 22: 23, 19: 17, 44: 48, 46: 46, 38: 39, 34: 46, 36: 46, 33: 46, 42: 30, 86: 49, 101: 50, 102: 52, 110: 35, 108: 51, 109: 54, 130: 22, 125: 24, 154: 5, 157: 3, 152: 5, 188: 2, 179: 1, 187: 1, 189: 2, 192: 1} (Minimum: 1)
#   File 2: {9: 1, 585: 1} (Minimum: 9)
#   File 3: {33: 31, 32: 4, 31: 6, 30: 4, 29: 4, 28: 4, 27: 4, 26: 5, 25: 3, 24: 5, 23: 5, 22: 4, 21: 5, 20: 4, 19: 5, 18: 4, 17: 5, 16: 5, 15: 4, 14: 4, 13: 7, 12: 5, 11: 7, 10: 8, 9: 8, 8: 13, 7: 20, 6: 23, 100: 5901, 99: 2, 98: 1, 97: 1, 96: 1, 95: 1, 94: 2, 93: 1, 92: 1, 91: 1, 90: 2, 89: 1, 88: 1, 87: 1, 86: 1, 85: 1, 84: 2, 83: 1, 82: 1, 81: 1, 80: 1, 79: 2, 78: 1, 76: 2, 75: 2, 74: 1, 73: 1, 72: 1, 71: 1, 70: 1, 69: 2, 68: 1, 67: 1, 66: 1, 65: 2, 64: 1, 63: 1, 62: 1, 61: 1, 60: 2, 59: 1, 58: 1, 57: 1, 56: 1, 55: 2, 53: 2, 52: 1, 51: 1, 50: 1, 49: 2, 48: 1, 47: 1, 46: 1, 45: 1, 44: 2, 43: 1, 42: 1, 41: 2, 40: 1, 39: 2, 38: 1, 37: 1, 36: 2, 35: 1, 34: 1, 5: 9} (Minimum: 5)
# Folder: 2023-10-16-10-50-24_tiksoja_ride_04_sfa
#   File 1: {6: 355, 8: 112, 7: 210, 5: 367, 9: 59, 10: 42, 11: 15, 13: 1, 12: 2, 4: 397, 2: 1268, 3: 646, 1: 3446} (Minimum: 1)
#   File 2: {286: 1, 34: 1, 645: 1, 478: 1, 374: 1, 424: 1} (Minimum: 34)
#   File 3: {59: 224, 58: 12, 57: 10, 56: 8, 55: 8, 54: 7, 53: 9, 52: 8, 51: 7, 50: 7, 49: 8, 48: 6, 47: 8, 46: 9, 45: 8, 44: 6, 43: 8, 42: 9, 41: 7, 40: 9, 39: 8, 38: 8, 37: 7, 36: 11, 35: 7, 34: 9, 33: 11, 32: 8, 31: 9, 30: 10, 29: 11, 28: 10, 27: 12, 26: 9, 25: 12, 24: 12, 23: 12, 22: 10, 21: 14, 20: 15, 19: 12, 18: 15, 17: 15, 16: 15, 15: 17, 14: 17, 13: 19, 12: 20, 11: 23, 10: 26, 9: 30, 8: 37, 7: 52, 6: 72, 100: 18510, 98: 5, 97: 4, 96: 3, 95: 4, 94: 5, 93: 5, 92: 4, 91: 4, 90: 5, 88: 5, 86: 5, 85: 4, 84: 5, 83: 4, 82: 4, 81: 5, 80: 4, 79: 5, 78: 4, 77: 4, 76: 4, 75: 5, 73: 4, 72: 5, 71: 5, 70: 5, 69: 4, 68: 4, 67: 5, 66: 4, 65: 6, 64: 4, 63: 6, 62: 4, 61: 6, 60: 4, 89: 3, 74: 4, 87: 3, 99: 2} (Minimum: 6)
# Folder: 2023-10-16-13-47-19_tiksoja_ride_05_cluster
#   File 1: {90: 88, 95: 74, 103: 81, 104: 69, 107: 92, 112: 67, 105: 81, 100: 74, 109: 70, 106: 70, 102: 63, 108: 74, 101: 71, 96: 68, 99: 63, 98: 57, 91: 99, 93: 92, 92: 101, 94: 84, 97: 47, 89: 132, 85: 129, 87: 125, 88: 120, 86: 116, 83: 101, 84: 99, 82: 112, 81: 93, 78: 59, 80: 102, 79: 75, 76: 69, 77: 52, 111: 59, 115: 64, 113: 53, 117: 54, 118: 59, 110: 62, 119: 63, 120: 50, 123: 44, 125: 51, 128: 41, 127: 35, 126: 43, 122: 46, 116: 69, 114: 51, 121: 46, 75: 62, 74: 44, 124: 47, 135: 30, 132: 36, 133: 33, 136: 26, 137: 33, 130: 29, 129: 37, 143: 31, 134: 24, 131: 36, 149: 25, 154: 27, 145: 26, 139: 25, 140: 13, 146: 28, 141: 31, 151: 18, 150: 21, 157: 22, 155: 16, 156: 29, 158: 24, 160: 22, 162: 19, 159: 17, 147: 20, 148: 19, 164: 13, 163: 13, 161: 13, 165: 9, 170: 5, 152: 18, 153: 18, 144: 20, 142: 21, 138: 26, 71: 48, 72: 56, 68: 45, 64: 50, 59: 54, 54: 58, 48: 34, 44: 52, 46: 38, 39: 56, 43: 39, 40: 66, 37: 76, 38: 72, 41: 57, 42: 54, 45: 33, 47: 42, 49: 47, 55: 39, 65: 52, 177: 2, 179: 5, 168: 5, 167: 8, 169: 9, 176: 4, 180: 5, 178: 5, 172: 8, 166: 10, 173: 5, 175: 8, 171: 8, 174: 2, 184: 3, 183: 3, 188: 4, 190: 5, 186: 4, 185: 5, 191: 1, 192: 3, 194: 1, 182: 2, 66: 55, 58: 43, 56: 46, 60: 40, 53: 40, 61: 41, 69: 34, 67: 54, 63: 52, 73: 53, 62: 46, 57: 50, 189: 5, 181: 2, 195: 2, 201: 1, 196: 2, 200: 1, 197: 1, 70: 44, 52: 48, 51: 42, 50: 36, 36: 72, 35: 78, 34: 93, 32: 57, 31: 81, 30: 64, 33: 78, 28: 74, 29: 63, 27: 64, 23: 36, 22: 35, 20: 29, 26: 53, 25: 49, 19: 14, 21: 26, 24: 41, 15: 5, 16: 8, 17: 16, 18: 13, 12: 2, 9: 1, 5: 7, 4: 18, 1: 133, 2: 99, 3: 34, 7: 7, 6: 4, 8: 5, 13: 3, 14: 3, 11: 1} (Minimum: 1)
#   File 2: {216: 1, 670: 1} (Minimum: 216)
#   File 3: {87: 3, 86: 4, 85: 4, 84: 4, 83: 4, 82: 3, 81: 5, 80: 5, 79: 5, 78: 5, 77: 6, 76: 6, 75: 9, 74: 10, 73: 541, 72: 12, 71: 6, 70: 5, 69: 4, 68: 4, 67: 4, 66: 3, 65: 4, 64: 3, 63: 3, 62: 4, 61: 3, 60: 3, 59: 4, 58: 2, 57: 3, 56: 4, 55: 3, 54: 3, 53: 4, 52: 3, 51: 3, 50: 5, 49: 3, 48: 4, 47: 4, 46: 3, 45: 5, 44: 3, 43: 4, 42: 5, 41: 4, 40: 5, 39: 3, 38: 5, 37: 4, 36: 5, 35: 4, 34: 5, 33: 4, 32: 4, 31: 5, 30: 5, 29: 5, 28: 5, 27: 5, 26: 4, 25: 5, 24: 5, 23: 5, 22: 5, 21: 5, 20: 5, 19: 5, 18: 5, 17: 5, 16: 5, 15: 6, 14: 5, 13: 5, 12: 6, 11: 6, 10: 7, 9: 7, 8: 9, 7: 11, 6: 18, 100: 7168, 99: 2, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 1, 92: 1, 91: 2, 90: 1, 89: 1, 88: 2} (Minimum: 6)
# Folder: 2023-10-16-15-23-20_tiksoja_ride_08_cluster
#   File 1: {58: 31, 59: 52, 57: 43, 61: 75, 65: 85, 66: 63, 60: 62, 52: 23, 48: 27, 49: 25, 54: 26, 46: 31, 43: 24, 39: 24, 36: 20, 28: 27, 26: 23, 25: 16, 27: 26, 29: 40, 30: 30, 31: 23, 41: 16, 40: 23, 38: 23, 45: 24, 44: 22, 47: 18, 53: 40, 56: 34, 51: 23, 50: 28, 55: 29, 62: 77, 64: 93, 68: 55, 71: 52, 70: 51, 63: 82, 69: 63, 67: 71, 72: 35, 73: 44, 76: 42, 77: 44, 79: 49, 80: 53, 74: 42, 75: 50, 81: 44, 78: 52, 82: 51, 86: 54, 87: 58, 91: 37, 88: 56, 97: 49, 104: 50, 90: 63, 99: 57, 105: 43, 111: 31, 113: 28, 106: 68, 114: 42, 116: 39, 110: 38, 120: 14, 119: 23, 121: 22, 118: 28, 107: 60, 102: 47, 96: 39, 100: 43, 98: 50, 101: 41, 94: 51, 92: 66, 85: 57, 83: 42, 84: 57, 95: 50, 93: 50, 103: 56, 89: 54, 109: 36, 108: 50, 124: 27, 117: 23, 112: 27, 42: 21, 37: 24, 115: 23, 123: 34, 125: 15, 126: 21, 122: 12, 127: 21, 129: 16, 131: 29, 130: 24, 128: 26, 135: 29, 141: 40, 140: 25, 145: 16, 146: 20, 149: 15, 147: 13, 148: 16, 155: 7, 152: 11, 144: 35, 143: 26, 138: 26, 151: 10, 136: 26, 139: 22, 142: 30, 134: 27, 137: 27, 132: 17, 133: 27, 150: 13, 156: 8, 159: 6, 162: 6, 164: 7, 161: 2, 158: 8, 157: 7, 163: 6, 160: 6, 154: 8, 153: 5, 172: 3, 174: 6, 166: 2, 165: 1, 168: 2, 170: 4, 177: 3, 173: 2, 169: 1, 167: 3, 179: 4, 34: 21, 33: 27, 32: 28, 24: 17, 21: 16, 20: 13, 23: 15, 22: 17, 19: 5, 18: 8, 17: 5, 16: 2, 35: 35, 171: 2, 180: 1, 178: 3, 187: 2, 192: 2, 189: 2, 188: 3, 182: 1, 184: 3, 196: 1, 191: 1, 190: 1, 183: 2, 175: 1, 185: 1, 176: 5} (Minimum: 16)
#   File 2: {39: 1, 315: 1} (Minimum: 39)
#   File 3: {100: 4355, 99: 2, 97: 2, 96: 2, 95: 3, 93: 2, 92: 2, 91: 2, 89: 2, 88: 2, 87: 3, 85: 2, 84: 2, 82: 3, 81: 3, 79: 2, 78: 2, 77: 2, 75: 3, 74: 2, 73: 2, 72: 2, 71: 2, 70: 2, 69: 3, 68: 2, 67: 2, 66: 2, 64: 2, 63: 3, 62: 2, 61: 3, 60: 2, 59: 2, 58: 2, 57: 3, 56: 2, 55: 2, 54: 2, 53: 3, 52: 2, 51: 3, 50: 2, 49: 3, 48: 2, 47: 2, 46: 3, 45: 2, 44: 3, 43: 3, 42: 2, 41: 4, 40: 2, 39: 4, 38: 1, 37: 4, 36: 3, 35: 3, 34: 3, 33: 4, 32: 2, 31: 4, 30: 4, 29: 3, 28: 4, 27: 4, 26: 4, 25: 5, 24: 4, 23: 5, 22: 5, 21: 5, 20: 5, 19: 5, 18: 6, 17: 5, 16: 5, 15: 6, 14: 7, 13: 6, 12: 6, 11: 8, 10: 8, 9: 10, 8: 11, 7: 18, 6: 23, 98: 1, 94: 1, 90: 1, 86: 1, 83: 1, 80: 1, 76: 1, 65: 1, 5: 7} (Minimum: 5)
# Folder: 2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2
#   File 1: {1: 1316, 2: 870, 3: 522, 4: 362, 5: 246, 7: 215, 6: 248, 8: 228, 9: 247, 10: 199, 11: 172, 12: 124, 13: 85, 14: 97, 15: 110, 17: 103, 18: 132, 16: 93, 21: 92, 19: 91, 20: 124, 22: 95, 23: 82, 24: 81, 25: 89, 26: 70, 27: 43, 28: 58, 29: 39, 30: 23, 31: 9, 32: 4, 33: 1} (Minimum: 1)
#   File 2: {2: 1, 817: 1} (Minimum: 2)
#   File 3: {13: 38, 12: 8, 11: 6, 10: 6, 9: 7, 8: 9, 7: 15, 6: 24, 5: 5, 100: 9452, 99: 1, 98: 1, 97: 2, 96: 1, 95: 2, 94: 1, 93: 2, 92: 1, 91: 2, 90: 1, 89: 2, 88: 1, 87: 2, 86: 2, 85: 2, 84: 3, 83: 2, 82: 3, 81: 3, 80: 3, 79: 3, 78: 3, 77: 3, 76: 3, 75: 2, 74: 3, 73: 3, 72: 3, 71: 2, 70: 2, 69: 2, 68: 2, 67: 2, 66: 2, 65: 2, 64: 2, 63: 2, 62: 2, 61: 2, 60: 2, 59: 2, 58: 2, 57: 2, 56: 2, 55: 2, 54: 2, 53: 2, 52: 3, 51: 2, 50: 2, 49: 2, 48: 3, 47: 2, 46: 2, 45: 2, 44: 2, 43: 2, 42: 3, 41: 2, 40: 2, 39: 3, 38: 2, 37: 2, 36: 3, 35: 2, 34: 2, 33: 2, 32: 3, 31: 2, 30: 2, 29: 2, 28: 3, 27: 2, 26: 2, 25: 3, 24: 2, 23: 3, 22: 2, 21: 2, 20: 3, 19: 2, 18: 2, 17: 3, 16: 2, 15: 2, 14: 3} (Minimum: 5)
# Folder: 2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1
#   File 1: {139: 42, 140: 37, 137: 50, 147: 21, 136: 40, 134: 38, 138: 43, 132: 37, 135: 40, 143: 22, 142: 26, 141: 25, 133: 41, 130: 40, 121: 59, 122: 61, 125: 54, 144: 22, 129: 46, 120: 72, 117: 63, 119: 72, 124: 60, 126: 57, 127: 63, 118: 66, 111: 53, 107: 43, 116: 52, 108: 49, 109: 45, 114: 46, 110: 40, 112: 56, 104: 46, 94: 61, 85: 63, 88: 66, 102: 56, 101: 72, 103: 46, 93: 58, 92: 56, 95: 70, 96: 55, 90: 51, 83: 53, 84: 60, 86: 53, 87: 60, 81: 55, 79: 64, 82: 63, 78: 71, 74: 72, 80: 51, 75: 57, 76: 66, 70: 78, 67: 67, 71: 66, 69: 51, 66: 53, 68: 53, 72: 74, 73: 70, 77: 47, 63: 47, 62: 43, 65: 49, 61: 44, 59: 52, 57: 48, 60: 42, 64: 49, 91: 46, 100: 46, 98: 66, 97: 51, 113: 51, 128: 54, 131: 34, 123: 61, 150: 21, 152: 21, 145: 21, 151: 25, 155: 17, 154: 21, 163: 7, 162: 15, 158: 15, 156: 15, 153: 16, 159: 10, 148: 23, 149: 20, 146: 23, 157: 13, 160: 13, 161: 10, 164: 8, 106: 39, 89: 39, 115: 47, 168: 6, 52: 35, 50: 26, 48: 21, 43: 39, 42: 45, 38: 72, 41: 59, 37: 68, 33: 76, 34: 96, 36: 82, 32: 81, 31: 91, 35: 72, 39: 62, 40: 48, 45: 27, 51: 36, 47: 25, 53: 37, 99: 47, 105: 69, 165: 7, 172: 8, 170: 5, 169: 6, 180: 2, 176: 1, 166: 8, 174: 5, 171: 5, 167: 4, 58: 36, 173: 4, 175: 2, 179: 3, 181: 3, 178: 3, 182: 1, 186: 2, 184: 2, 183: 1, 197: 2, 208: 1, 201: 1, 203: 1, 193: 1, 190: 2, 195: 1, 194: 1, 191: 2, 189: 1, 185: 3, 187: 1, 188: 3, 177: 2, 54: 34, 55: 47, 56: 38, 44: 21, 30: 55, 28: 40, 24: 44, 29: 60, 20: 30, 21: 26, 26: 60, 22: 33, 19: 14, 23: 26, 25: 44, 27: 46, 46: 26, 49: 21, 16: 12, 18: 16, 17: 12, 12: 6, 15: 3, 10: 3, 9: 3, 6: 7, 2: 102, 1: 196, 4: 15, 3: 30, 5: 5, 7: 3, 8: 2, 13: 1, 14: 4} (Minimum: 1)
#   File 2: {180: 1, 670: 1} (Minimum: 180)
#   File 3: {50: 4, 49: 4, 48: 4, 47: 4, 46: 4, 45: 4, 44: 4, 43: 5, 42: 4, 41: 4, 40: 5, 39: 4, 38: 5, 37: 4, 36: 5, 35: 5, 34: 4, 33: 4, 32: 5, 31: 4, 30: 5, 29: 5, 28: 5, 27: 3, 26: 7, 25: 5, 24: 4, 23: 5, 22: 5, 21: 5, 20: 5, 19: 6, 18: 4, 17: 6, 16: 5, 15: 6, 14: 4, 13: 6, 12: 6, 11: 6, 10: 7, 9: 7, 8: 8, 7: 13, 6: 16, 100: 6989, 99: 2, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 1, 92: 1, 91: 2, 90: 1, 89: 1, 88: 1, 87: 2, 86: 1, 85: 2, 84: 1, 83: 1, 82: 2, 81: 1, 80: 1, 79: 2, 78: 1, 77: 1, 76: 2, 75: 1, 74: 1, 73: 1, 72: 2, 71: 1, 70: 1, 69: 2, 68: 1, 67: 1, 66: 2, 65: 1, 64: 2, 63: 1, 62: 1, 61: 1, 60: 2, 59: 1, 58: 1, 57: 2, 56: 1, 55: 1, 54: 2, 53: 1, 52: 1, 51: 2} (Minimum: 6)
# Folder: 2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2
#   File 1: {137: 54, 132: 45, 133: 51, 128: 37, 131: 42, 141: 53, 139: 50, 138: 57, 142: 59, 143: 46, 136: 62, 135: 46, 140: 63, 134: 62, 146: 44, 145: 53, 144: 46, 130: 43, 152: 40, 148: 40, 127: 46, 129: 59, 123: 60, 121: 75, 125: 56, 124: 70, 126: 50, 120: 84, 117: 55, 118: 68, 119: 67, 116: 74, 113: 61, 115: 70, 112: 57, 114: 72, 122: 69, 150: 41, 155: 16, 151: 44, 153: 31, 157: 13, 160: 18, 154: 26, 158: 20, 147: 47, 149: 42, 156: 22, 159: 17, 110: 64, 108: 75, 103: 101, 106: 92, 107: 78, 109: 66, 102: 112, 101: 101, 105: 101, 94: 79, 97: 73, 84: 90, 86: 61, 96: 88, 98: 95, 87: 77, 88: 78, 93: 80, 91: 97, 92: 91, 89: 85, 85: 81, 78: 86, 77: 96, 73: 73, 68: 91, 67: 62, 72: 84, 76: 113, 74: 90, 82: 83, 99: 97, 100: 97, 90: 78, 95: 79, 80: 66, 71: 81, 63: 51, 57: 77, 65: 52, 62: 61, 55: 65, 59: 68, 60: 68, 58: 71, 69: 75, 70: 72, 64: 63, 75: 92, 66: 59, 81: 109, 79: 91, 54: 58, 52: 47, 53: 53, 47: 33, 45: 34, 48: 29, 51: 49, 50: 41, 49: 41, 61: 57, 56: 67, 42: 41, 38: 39, 37: 39, 32: 60, 30: 67, 31: 59, 27: 74, 25: 51, 21: 11, 23: 20, 26: 62, 36: 46, 28: 77, 24: 46, 29: 89, 18: 11, 19: 12, 16: 10, 14: 5, 12: 3, 15: 3, 13: 4, 10: 4, 9: 7, 11: 1, 5: 29, 3: 57, 2: 127, 4: 35, 1: 170, 6: 23, 7: 13, 8: 6, 17: 5, 22: 13, 34: 56, 46: 38, 41: 27, 39: 30, 44: 31, 35: 71, 33: 66, 40: 29, 43: 22, 83: 78, 104: 93, 111: 43, 162: 9, 161: 13, 165: 9, 164: 10, 171: 9, 163: 9, 170: 4, 172: 4, 169: 1, 167: 3, 173: 2, 168: 5, 20: 9, 166: 8, 176: 6, 174: 2, 177: 4, 185: 4, 184: 2, 178: 3, 179: 3, 180: 3, 181: 2, 193: 2, 197: 1, 199: 2, 194: 1, 189: 3, 186: 1, 196: 1, 198: 2, 202: 1, 207: 1, 192: 4, 175: 4, 182: 2, 188: 3, 187: 2} (Minimum: 1)
#   File 2: {765: 1} (Minimum: 765)
#   File 3: {100: 8754, 99: 1, 98: 2, 97: 1, 96: 2, 95: 1, 94: 2, 93: 1, 92: 1, 91: 2, 90: 1, 89: 2, 88: 1, 87: 1, 86: 2, 85: 1, 84: 2, 83: 1, 82: 2, 81: 1, 80: 2, 79: 1, 78: 2, 77: 1, 76: 2, 75: 1, 74: 2, 73: 1, 72: 2, 71: 1, 70: 2, 69: 1, 68: 2, 67: 1, 66: 2, 65: 1, 64: 2, 63: 2, 62: 1, 61: 2, 60: 2, 59: 1, 58: 2, 57: 2, 56: 2, 55: 2, 54: 1, 53: 2, 52: 2, 51: 2, 50: 2, 49: 2, 48: 2, 47: 2, 46: 3, 45: 1, 44: 3, 43: 2, 42: 2, 41: 2, 40: 3, 39: 2, 38: 2, 37: 3, 36: 2, 35: 2, 34: 3, 33: 2, 32: 3, 31: 3, 30: 2, 29: 3, 28: 2, 27: 3, 26: 3, 25: 3, 24: 3, 23: 3, 22: 3, 21: 4, 20: 5, 19: 253, 18: 10, 17: 6, 16: 5, 15: 5, 14: 5, 13: 6, 12: 8, 11: 8, 10: 6, 9: 4, 8: 4, 7: 5, 6: 5} (Minimum: 6)
# Folder: 2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1
#   File 1: {111: 35, 106: 52, 113: 45, 116: 53, 118: 61, 110: 39, 109: 48, 114: 40, 108: 46, 107: 44, 100: 54, 102: 68, 103: 60, 104: 64, 105: 56, 115: 56, 112: 35, 117: 68, 93: 45, 90: 46, 85: 45, 76: 45, 73: 70, 80: 48, 78: 44, 72: 42, 77: 56, 83: 47, 75: 50, 74: 56, 68: 46, 64: 46, 61: 52, 66: 52, 70: 50, 71: 39, 69: 40, 65: 59, 67: 44, 63: 53, 60: 47, 59: 47, 82: 60, 84: 59, 86: 46, 81: 54, 87: 42, 88: 55, 89: 62, 92: 48, 97: 60, 95: 58, 96: 36, 98: 66, 99: 50, 91: 50, 94: 45, 101: 52, 120: 69, 122: 51, 131: 31, 129: 29, 128: 22, 132: 23, 126: 40, 124: 48, 125: 37, 119: 60, 121: 53, 123: 55, 138: 33, 144: 70, 142: 57, 134: 21, 130: 28, 127: 35, 136: 28, 141: 46, 137: 23, 135: 23, 133: 25, 150: 27, 156: 17, 162: 9, 159: 19, 164: 7, 165: 6, 163: 5, 157: 15, 151: 24, 160: 11, 171: 7, 175: 5, 179: 5, 172: 13, 169: 4, 174: 5, 168: 5, 170: 5, 177: 8, 180: 4, 176: 11, 178: 4, 183: 9, 154: 14, 146: 50, 140: 40, 166: 10, 185: 4, 191: 2, 198: 1, 193: 1, 197: 1, 199: 2, 186: 4, 182: 5, 190: 3, 188: 1, 187: 1, 192: 1, 167: 5, 155: 13, 152: 26, 148: 44, 149: 37, 147: 43, 145: 69, 143: 58, 153: 14, 79: 49, 56: 49, 53: 43, 54: 38, 50: 32, 58: 44, 52: 44, 57: 43, 62: 58, 55: 48, 47: 29, 48: 32, 45: 35, 44: 38, 42: 54, 46: 31, 36: 81, 37: 70, 34: 93, 31: 106, 32: 93, 33: 105, 29: 82, 30: 96, 38: 80, 35: 84, 27: 75, 25: 44, 24: 64, 28: 73, 26: 51, 23: 52, 19: 27, 18: 18, 20: 29, 21: 33, 17: 18, 22: 36, 39: 74, 40: 45, 41: 54, 43: 41, 49: 38, 16: 22, 15: 12, 51: 31, 139: 34, 158: 6, 161: 5, 173: 3, 14: 12, 6: 31, 4: 46, 1: 205, 2: 130, 3: 85, 8: 34, 11: 12, 9: 20, 5: 22, 7: 26, 12: 14, 13: 18, 10: 12, 189: 2, 181: 3, 184: 1} (Minimum: 1)
#   File 2: {33: 1, 686: 1} (Minimum: 33)
#   File 3: {87: 2, 86: 4, 85: 2, 84: 4, 83: 3, 82: 3, 81: 3, 80: 2, 79: 2, 78: 3, 77: 3, 76: 3, 75: 2, 74: 2, 73: 3, 72: 3, 71: 1, 70: 2, 69: 3, 68: 2, 67: 2, 66: 3, 65: 2, 64: 3, 63: 2, 62: 2, 61: 2, 60: 2, 59: 2, 58: 3, 57: 2, 56: 2, 55: 3, 54: 2, 53: 3, 52: 2, 51: 2, 50: 2, 49: 3, 48: 3, 47: 2, 46: 2, 45: 2, 44: 3, 43: 3, 42: 2, 41: 3, 40: 2, 39: 3, 38: 3, 37: 2, 36: 3, 35: 3, 34: 3, 33: 3, 32: 3, 31: 3, 30: 4, 29: 2, 28: 4, 27: 4, 26: 4, 25: 3, 24: 4, 23: 4, 22: 4, 21: 5, 20: 5, 19: 4, 18: 4, 17: 6, 16: 4, 15: 6, 14: 6, 13: 6, 12: 7, 11: 6, 10: 9, 9: 9, 8: 12, 7: 17, 6: 24, 100: 7428, 99: 1, 97: 1, 96: 1, 95: 1, 93: 1, 92: 1, 91: 1, 89: 1, 88: 1} (Minimum: 6)
# Folder: 2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2
#   File 1: {30: 73, 31: 78, 32: 77, 33: 69, 27: 80, 28: 65, 29: 77, 34: 69, 35: 50, 37: 56, 42: 47, 46: 40, 43: 40, 41: 43, 39: 56, 40: 45, 38: 52, 45: 49, 47: 43, 51: 37, 49: 46, 52: 57, 53: 49, 50: 46, 48: 47, 54: 61, 58: 66, 57: 67, 55: 60, 44: 41, 36: 45, 22: 52, 20: 44, 15: 28, 12: 17, 11: 17, 9: 24, 8: 30, 6: 45, 4: 53, 3: 72, 7: 31, 5: 46, 14: 19, 17: 42, 21: 48, 23: 52, 25: 66, 19: 56, 24: 65, 26: 61, 16: 33, 18: 48, 13: 16, 10: 9, 59: 66, 56: 55, 60: 63, 61: 66, 62: 74, 63: 63, 2: 116, 1: 212, 67: 45, 69: 66, 68: 46, 65: 63, 75: 51, 77: 58, 73: 66, 80: 66, 79: 57, 64: 74, 72: 61, 85: 65, 76: 60, 66: 59, 74: 71, 70: 53, 84: 58, 89: 78, 97: 74, 94: 73, 95: 76, 90: 58, 93: 70, 99: 71, 103: 55, 107: 62, 105: 70, 109: 40, 110: 49, 114: 33, 106: 50, 113: 37, 112: 48, 101: 60, 118: 38, 121: 38, 122: 25, 123: 19, 120: 33, 126: 16, 128: 23, 129: 23, 136: 20, 133: 20, 132: 27, 130: 19, 125: 27, 127: 21, 124: 21, 135: 20, 131: 26, 117: 26, 134: 24, 138: 17, 119: 27, 116: 41, 137: 18, 147: 28, 146: 21, 161: 8, 163: 6, 159: 4, 173: 6, 158: 7, 162: 9, 164: 7, 171: 4, 168: 9, 175: 4, 183: 3, 179: 5, 176: 5, 174: 4, 170: 5, 144: 21, 139: 28, 142: 12, 108: 56, 92: 57, 100: 64, 98: 73, 96: 68, 104: 68, 102: 62, 91: 53, 81: 67, 82: 43, 83: 55, 78: 69, 88: 57, 141: 26, 153: 13, 152: 10, 148: 10, 140: 15, 115: 41, 150: 20, 149: 16, 160: 5, 151: 15, 154: 10, 145: 7, 143: 13, 86: 70, 111: 33, 87: 57, 71: 62, 155: 8, 157: 4, 169: 5, 165: 4, 156: 2, 166: 8, 172: 2, 167: 1, 178: 2, 191: 1, 198: 1, 199: 1, 185: 2, 190: 1, 196: 1, 187: 1, 181: 3, 188: 1, 186: 2, 184: 1, 177: 3, 182: 1, 180: 2} (Minimum: 1)
#   File 2: {10: 1, 661: 1} (Minimum: 10)
#   File 3: {100: 6938, 99: 2, 98: 2, 97: 2, 96: 3, 95: 2, 94: 2, 93: 2, 92: 3, 91: 2, 90: 2, 89: 2, 88: 2, 87: 3, 86: 1, 85: 2, 84: 3, 83: 2, 82: 2, 80: 2, 79: 3, 78: 2, 77: 2, 76: 2, 75: 2, 74: 2, 73: 2, 71: 3, 70: 2, 69: 2, 68: 2, 67: 2, 66: 2, 64: 2, 63: 2, 62: 2, 61: 2, 60: 3, 59: 1, 58: 3, 57: 2, 55: 2, 54: 2, 53: 3, 52: 2, 51: 2, 50: 3, 49: 1, 48: 3, 47: 3, 46: 2, 45: 2, 44: 3, 43: 2, 42: 3, 41: 2, 40: 3, 39: 3, 38: 3, 37: 2, 36: 4, 35: 2, 34: 4, 33: 2, 32: 4, 31: 2, 30: 4, 29: 4, 28: 4, 27: 3, 26: 4, 25: 4, 24: 5, 23: 4, 22: 5, 21: 4, 20: 5, 19: 5, 18: 5, 17: 7, 16: 4, 15: 6, 14: 6, 13: 7, 12: 7, 11: 8, 10: 8, 9: 10, 8: 13, 7: 18, 6: 22, 81: 1, 72: 1, 65: 2, 56: 1, 5: 8} (Minimum: 5)
# Folder: 2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1
#   File 1: {12: 146, 13: 117, 14: 65, 9: 310, 8: 304, 11: 232, 10: 240, 15: 79, 17: 67, 16: 53, 18: 69, 19: 48, 21: 34, 22: 27, 23: 24, 25: 26, 26: 20, 20: 34, 24: 24, 27: 17, 28: 6, 30: 5, 29: 5, 32: 4, 31: 3, 33: 5, 34: 6, 36: 4, 35: 3, 38: 3, 41: 4, 39: 5, 43: 1, 42: 2, 40: 1, 7: 354, 5: 487, 4: 448, 3: 559, 2: 714, 1: 933, 6: 393} (Minimum: 1)
#   File 2: {225: 1, 138: 1, 763: 1} (Minimum: 138)
#   File 3: {57: 3, 56: 3, 55: 3, 54: 3, 53: 4, 52: 3, 51: 3, 50: 4, 49: 3, 48: 4, 47: 3, 46: 3, 45: 4, 44: 3, 43: 4, 42: 4, 41: 3, 40: 4, 39: 3, 38: 5, 37: 3, 36: 4, 35: 4, 34: 4, 33: 5, 32: 3, 31: 5, 30: 4, 29: 5, 28: 4, 27: 5, 26: 4, 25: 5, 24: 4, 23: 5, 22: 4, 21: 5, 20: 5, 19: 5, 18: 5, 17: 4, 16: 6, 15: 4, 14: 6, 13: 5, 12: 5, 11: 6, 10: 6, 9: 7, 8: 9, 7: 12, 6: 18, 100: 8615, 99: 1, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 1, 92: 1, 91: 2, 90: 1, 89: 1, 88: 2, 87: 1, 86: 1, 85: 2, 84: 1, 83: 1, 82: 2, 81: 1, 80: 1, 79: 2, 78: 1, 77: 1, 76: 2, 75: 1, 74: 1, 73: 2, 72: 1, 71: 1, 70: 1, 69: 2, 68: 1, 67: 1, 66: 2, 65: 1, 64: 1, 63: 2, 62: 1, 61: 1, 60: 2, 59: 1, 58: 1} (Minimum: 6)
# Folder: 2023-10-30-15-04-36_tiksoja_ride_13_cluster_split_1
#   File 1: {84: 66, 82: 67, 77: 61, 78: 77, 79: 72, 91: 60, 88: 74, 90: 61, 95: 73, 94: 66, 92: 55, 93: 66, 96: 81, 98: 81, 97: 90, 100: 89, 104: 48, 89: 57, 101: 71, 106: 66, 109: 63, 108: 59, 112: 65, 115: 77, 105: 76, 103: 71, 119: 89, 114: 51, 111: 56, 110: 55, 113: 56, 102: 78, 99: 58, 107: 66, 117: 69, 85: 64, 118: 55, 127: 58, 137: 31, 141: 36, 142: 34, 132: 30, 134: 24, 135: 24, 138: 28, 136: 33, 139: 38, 130: 36, 122: 85, 123: 83, 121: 69, 116: 63, 124: 95, 129: 48, 131: 30, 126: 53, 125: 42, 87: 65, 81: 65, 86: 56, 80: 76, 70: 87, 71: 51, 75: 66, 65: 55, 59: 64, 58: 63, 60: 65, 63: 56, 69: 73, 66: 53, 67: 58, 72: 79, 73: 65, 74: 67, 83: 57, 76: 65, 62: 64, 64: 43, 56: 55, 61: 62, 55: 63, 52: 62, 53: 59, 57: 67, 54: 58, 50: 63, 49: 58, 68: 57, 44: 41, 48: 45, 46: 48, 45: 41, 51: 45, 128: 38, 120: 77, 143: 42, 140: 33, 147: 13, 148: 19, 144: 37, 146: 22, 151: 15, 149: 15, 152: 14, 155: 13, 154: 7, 145: 31, 42: 35, 40: 42, 35: 71, 39: 50, 133: 21, 163: 5, 158: 6, 153: 9, 157: 6, 150: 10, 159: 6, 162: 5, 160: 5, 164: 3, 161: 3, 179: 1, 178: 1, 166: 2, 156: 2, 168: 1, 165: 1, 167: 2, 169: 1, 172: 1, 43: 35, 38: 45, 36: 68, 32: 103, 29: 98, 37: 46, 27: 95, 26: 92, 30: 100, 31: 107, 34: 86, 33: 91, 28: 87, 25: 69, 24: 74, 41: 39, 47: 54, 23: 56, 22: 58, 21: 59, 20: 42, 19: 32, 18: 25, 16: 16, 13: 5, 14: 9, 11: 6, 10: 4, 15: 15, 17: 14, 9: 3, 6: 5, 4: 21, 2: 83, 1: 127, 3: 31, 5: 8, 8: 6, 7: 2, 12: 3} (Minimum: 1)
#   File 2: {138: 1, 763: 1} (Minimum: 138)
#   File 3: {100: 8254, 99: 2, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 1, 92: 1, 91: 1, 90: 2, 89: 1, 88: 1, 87: 2, 86: 1, 85: 1, 84: 1, 83: 2, 82: 1, 81: 1, 80: 2, 79: 1, 78: 1, 77: 2, 76: 1, 75: 2, 74: 1, 73: 1, 72: 1, 71: 2, 70: 1, 69: 1, 68: 1, 67: 2, 66: 1, 65: 1, 64: 2, 63: 1, 62: 1, 61: 2, 60: 1, 59: 1, 58: 2, 57: 1, 56: 1, 55: 2, 54: 1, 53: 1, 52: 2, 51: 1, 50: 1, 49: 2, 48: 1, 47: 2, 46: 1, 45: 1, 44: 2, 43: 1, 42: 1, 41: 2, 40: 1, 39: 2, 38: 1, 37: 2, 36: 1, 35: 2, 34: 2, 33: 1, 32: 2, 31: 2, 30: 2, 29: 2, 28: 1, 27: 2, 26: 2, 25: 2, 24: 3, 23: 2, 22: 2, 21: 2, 20: 2, 19: 3, 18: 1, 17: 3, 16: 2, 15: 3, 14: 3, 13: 2, 12: 3, 11: 3, 10: 3, 9: 3, 8: 5, 7: 6, 6: 8} (Minimum: 6)
# Folder: 2023-10-30-15-19-32_tiksoja_ride_13_cluster_split_2
#   File 1: {126: 119, 114: 94, 112: 70, 110: 68, 115: 117, 117: 100, 108: 47, 119: 123, 125: 127, 120: 114, 116: 94, 118: 117, 122: 133, 121: 150, 124: 139, 128: 97, 135: 47, 133: 69, 113: 80, 123: 128, 129: 85, 106: 76, 111: 77, 109: 67, 127: 120, 107: 51, 137: 70, 136: 61, 131: 68, 105: 90, 104: 87, 130: 67, 139: 63, 138: 72, 134: 64, 141: 55, 150: 44, 140: 48, 144: 50, 146: 45, 145: 48, 149: 63, 103: 86, 101: 105, 155: 58, 167: 24, 165: 28, 161: 26, 157: 45, 158: 37, 159: 44, 162: 27, 147: 55, 99: 100, 102: 94, 132: 65, 100: 88, 97: 112, 96: 82, 91: 100, 85: 106, 84: 79, 92: 96, 89: 105, 95: 90, 88: 79, 83: 86, 82: 76, 80: 68, 78: 81, 77: 65, 68: 76, 65: 62, 63: 63, 56: 50, 54: 41, 59: 60, 70: 52, 74: 64, 71: 58, 81: 87, 73: 60, 72: 53, 76: 65, 69: 49, 75: 57, 87: 95, 94: 92, 93: 99, 98: 95, 90: 82, 86: 95, 67: 59, 61: 63, 58: 57, 64: 62, 62: 70, 60: 63, 51: 49, 53: 42, 57: 46, 79: 81, 66: 53, 52: 48, 46: 35, 42: 43, 38: 58, 39: 48, 49: 44, 47: 34, 40: 45, 44: 56, 45: 41, 43: 51, 50: 47, 48: 52, 41: 43, 37: 43, 31: 51, 26: 42, 28: 51, 25: 64, 27: 41, 23: 54, 24: 55, 30: 51, 33: 54, 32: 35, 35: 53, 34: 59, 22: 47, 20: 52, 19: 30, 17: 18, 15: 10, 13: 5, 14: 4, 16: 12, 18: 24, 11: 4, 7: 3, 4: 9, 3: 34, 2: 136, 5: 9, 1: 396, 6: 5, 8: 5, 10: 5, 12: 1, 21: 33, 29: 47, 36: 43, 55: 42, 143: 52, 142: 47, 148: 56, 152: 42, 153: 33, 151: 42, 154: 43, 156: 49, 170: 20, 168: 17, 164: 19, 163: 19, 171: 6, 174: 12, 178: 6, 181: 6, 179: 8, 177: 8, 180: 8, 175: 3, 172: 5, 176: 7, 169: 16, 160: 28, 166: 16, 173: 5, 182: 3, 188: 4, 183: 9, 186: 4, 185: 4, 184: 4, 190: 4, 200: 4, 194: 1, 189: 3, 187: 2, 195: 1, 193: 1, 196: 1, 191: 1, 192: 1} (Minimum: 1)
#   File 2: {677: 1, 909: 1} (Minimum: 677)
#   File 3: {100: 10314, 99: 1, 98: 2, 97: 1, 96: 1, 95: 2, 94: 1, 93: 2, 92: 1, 91: 1, 90: 2, 89: 1, 88: 2, 87: 1, 86: 2, 85: 1, 84: 2, 83: 1, 82: 2, 81: 1, 80: 1, 79: 1, 78: 2, 77: 2, 76: 1, 75: 2, 74: 1, 73: 2, 72: 1, 71: 2, 70: 1, 69: 1, 68: 2, 67: 2, 66: 1, 65: 2, 64: 1, 63: 2, 62: 1, 61: 2, 60: 2, 59: 1, 58: 2, 57: 2, 56: 1, 55: 2, 54: 2, 53: 2, 52: 2, 51: 2, 50: 3, 49: 2, 48: 2, 47: 2, 46: 3, 45: 2, 44: 2, 43: 3, 42: 2, 41: 3, 40: 3, 39: 2, 38: 3, 37: 3, 36: 2, 35: 3, 34: 3, 33: 3, 32: 2, 31: 3, 30: 3, 29: 3, 28: 3, 27: 2, 26: 3, 25: 3, 24: 3, 23: 2, 22: 3, 21: 3, 20: 3, 19: 2, 18: 3, 17: 3, 16: 2, 15: 3, 14: 3, 13: 3, 12: 3, 11: 2, 10: 4, 9: 3, 8: 5, 7: 5, 6: 9} (Minimum: 6)
# Folder: 2023-10-31-09-57-58_tiksoja_ride_14_sfa_split_1
#   File 1: {21: 40, 23: 41, 20: 41, 22: 35, 24: 17, 25: 22, 26: 7, 19: 46, 18: 55, 17: 65, 15: 97, 13: 114, 10: 188, 9: 279, 11: 151, 12: 135, 16: 76, 14: 109, 27: 3, 28: 3, 8: 357, 7: 443, 6: 479, 5: 508, 4: 512, 3: 699, 2: 1007, 1: 1292} (Minimum: 1)
#   File 2: {84: 1, 138: 1, 1082: 1} (Minimum: 84)
#   File 3: {62: 3, 61: 4, 60: 3, 59: 4, 58: 3, 57: 3, 56: 3, 55: 3, 54: 4, 53: 3, 52: 3, 51: 3, 50: 4, 49: 3, 48: 3, 47: 3, 46: 4, 45: 3, 44: 4, 43: 3, 42: 4, 41: 3, 40: 4, 39: 4, 38: 4, 37: 4, 36: 3, 35: 5, 34: 3, 33: 5, 32: 4, 31: 4, 30: 5, 29: 4, 28: 4, 27: 5, 26: 4, 25: 5, 24: 5, 23: 5, 22: 4, 21: 5, 20: 6, 19: 4, 18: 6, 17: 4, 16: 6, 15: 4, 14: 6, 13: 6, 12: 6, 11: 7, 10: 6, 9: 9, 8: 11, 7: 14, 6: 23, 100: 11120, 99: 1, 97: 1, 96: 1, 95: 1, 94: 1, 92: 1, 91: 1, 89: 1, 88: 1, 87: 1, 85: 1, 84: 1, 83: 1, 82: 1, 80: 1, 79: 1, 78: 1, 77: 1, 76: 1, 74: 1, 73: 1, 72: 1, 71: 1, 70: 1, 69: 1, 68: 1, 67: 1, 66: 1, 65: 1, 64: 1, 63: 1} (Minimum: 6)
# Folder: 2023-10-31-10-17-12_tiksoja_ride_14_sfa_split_2
#   File 1: {1: 1557, 2: 995, 3: 658, 4: 499, 5: 519, 6: 451, 8: 213, 9: 221, 7: 300, 10: 210, 11: 206, 13: 262, 12: 234, 15: 298, 14: 284, 16: 212, 17: 176, 18: 139, 19: 95, 20: 80, 21: 77, 23: 80, 22: 69, 24: 72, 26: 61, 25: 56, 27: 60, 31: 31, 29: 39, 30: 30, 28: 45, 33: 20, 32: 26, 34: 25, 36: 11, 37: 11, 39: 5, 41: 2, 38: 7, 35: 14, 40: 2, 44: 6, 49: 2, 46: 4, 47: 3, 43: 1, 42: 3, 45: 2} (Minimum: 1)
#   File 2: {12: 1, 914: 1, 1191: 1} (Minimum: 12)
#   File 3: {91: 5, 90: 4, 89: 5, 88: 6, 87: 5, 86: 4, 85: 6, 84: 4, 83: 5, 82: 5, 81: 4, 80: 5, 79: 5, 78: 4, 77: 5, 76: 5, 75: 6, 74: 6, 73: 25, 72: 13, 71: 5, 70: 6, 69: 4, 68: 4, 67: 4, 66: 4, 65: 4, 64: 3, 63: 3, 62: 3, 61: 3, 60: 3, 59: 3, 58: 3, 57: 4, 56: 3, 55: 3, 54: 3, 53: 2, 52: 4, 51: 3, 50: 3, 49: 3, 48: 5, 47: 3, 46: 3, 45: 4, 44: 3, 43: 4, 42: 3, 41: 4, 40: 3, 39: 4, 38: 4, 37: 5, 36: 3, 35: 4, 34: 4, 33: 4, 32: 4, 31: 4, 30: 5, 29: 4, 28: 5, 27: 4, 26: 4, 25: 5, 24: 5, 23: 4, 22: 5, 21: 5, 20: 5, 19: 5, 18: 6, 17: 4, 16: 6, 15: 6, 14: 6, 13: 5, 12: 8, 11: 7, 10: 8, 9: 9, 8: 11, 7: 16, 6: 21, 100: 12873, 99: 2, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 2, 92: 1} (Minimum: 6)
# Folder: 2023-10-31-10-41-16_tiksoja_ride_15_cluster_split_1
#   File 1: {74: 81, 76: 77, 79: 67, 78: 89, 71: 83, 72: 75, 75: 92, 73: 93, 80: 81, 81: 69, 69: 72, 77: 89, 82: 75, 84: 78, 87: 62, 85: 79, 86: 67, 88: 74, 89: 51, 91: 75, 95: 69, 96: 66, 97: 86, 93: 81, 94: 61, 90: 70, 92: 65, 99: 68, 98: 64, 101: 74, 103: 55, 106: 53, 110: 52, 108: 63, 111: 56, 107: 56, 109: 61, 104: 66, 100: 85, 113: 46, 116: 51, 105: 55, 102: 61, 112: 48, 119: 66, 83: 73, 70: 82, 68: 54, 67: 86, 66: 69, 65: 75, 62: 81, 60: 73, 58: 73, 57: 72, 55: 61, 52: 57, 50: 55, 49: 73, 47: 93, 44: 103, 46: 109, 45: 104, 43: 105, 48: 71, 54: 72, 51: 55, 53: 54, 64: 76, 63: 74, 118: 49, 117: 49, 120: 49, 114: 56, 122: 75, 121: 51, 129: 97, 127: 90, 115: 51, 61: 64, 56: 63, 59: 80, 125: 83, 128: 91, 138: 47, 136: 53, 144: 34, 146: 31, 148: 30, 137: 43, 123: 64, 131: 79, 126: 80, 124: 67, 134: 53, 142: 35, 147: 31, 150: 23, 155: 24, 141: 44, 133: 55, 139: 51, 135: 64, 130: 68, 140: 46, 145: 28, 151: 22, 152: 32, 153: 25, 154: 22, 165: 6, 171: 10, 164: 6, 166: 16, 161: 9, 157: 14, 158: 19, 160: 12, 132: 71, 143: 33, 149: 24, 156: 14, 159: 6, 162: 8, 167: 6, 170: 3, 172: 3, 178: 7, 180: 8, 188: 1, 197: 1, 189: 1, 195: 1, 190: 1, 179: 4, 169: 10, 174: 6, 173: 2, 176: 5, 39: 50, 42: 103, 41: 88, 37: 90, 33: 59, 36: 87, 34: 77, 35: 83, 32: 74, 38: 68, 31: 63, 30: 79, 40: 84, 29: 71, 27: 65, 26: 70, 28: 61, 25: 64, 23: 46, 24: 52, 21: 35, 22: 43, 20: 32, 18: 24, 163: 8, 168: 2, 19: 25, 17: 26, 12: 40, 8: 72, 5: 61, 1: 120, 2: 153, 4: 87, 3: 72, 7: 71, 6: 69, 11: 26, 14: 34, 13: 27, 10: 61, 16: 16, 184: 3, 185: 1, 186: 2, 183: 3, 177: 3, 175: 3, 181: 2, 182: 1, 191: 1, 9: 50, 15: 31} (Minimum: 1)
#   File 2: {138: 1, 925: 1} (Minimum: 138)
#   File 3: {100: 10107, 99: 1, 98: 1, 97: 1, 95: 1, 94: 1, 92: 1, 91: 1, 90: 1, 88: 1, 87: 1, 86: 1, 84: 1, 83: 1, 82: 1, 81: 1, 79: 1, 78: 1, 77: 1, 76: 1, 74: 1, 73: 1, 72: 1, 71: 1, 70: 1, 69: 1, 68: 1, 67: 1, 66: 2, 65: 1, 64: 1, 63: 2, 62: 1, 61: 2, 60: 1, 59: 1, 58: 1, 57: 1, 56: 2, 55: 1, 54: 1, 53: 1, 52: 1, 51: 1, 50: 1, 49: 1, 48: 2, 47: 1, 45: 1, 44: 2, 43: 1, 42: 1, 41: 1, 40: 1, 39: 1, 38: 2, 37: 1, 36: 1, 35: 1, 34: 1, 33: 1, 32: 2, 31: 1, 30: 1, 29: 2, 28: 1, 27: 2, 26: 2, 25: 2, 24: 2, 23: 2, 22: 2, 21: 2, 20: 2, 19: 2, 18: 3, 17: 3, 16: 2, 15: 3, 14: 4, 13: 3, 12: 3, 11: 5, 10: 4, 9: 5, 8: 8, 7: 9, 6: 12} (Minimum: 6)
# Folder: 2023-10-31-10-59-27_tiksoja_ride_15_cluster_split_2
#   File 1: {66: 81, 63: 104, 60: 94, 54: 87, 56: 103, 62: 103, 64: 97, 65: 93, 58: 87, 57: 114, 61: 103, 59: 101, 55: 99, 67: 85, 71: 124, 73: 99, 68: 91, 53: 88, 47: 86, 49: 82, 52: 74, 48: 80, 50: 59, 46: 91, 41: 84, 37: 89, 40: 71, 39: 83, 38: 86, 36: 81, 31: 86, 33: 117, 32: 97, 30: 86, 35: 78, 42: 63, 43: 59, 45: 80, 44: 79, 51: 86, 69: 104, 70: 119, 72: 102, 75: 99, 76: 110, 77: 97, 79: 110, 74: 90, 78: 98, 81: 128, 83: 149, 82: 127, 80: 117, 85: 135, 28: 75, 29: 85, 27: 83, 34: 83, 25: 91, 26: 74, 23: 54, 24: 79, 22: 64, 17: 40, 8: 63, 6: 109, 7: 66, 5: 157, 4: 175, 2: 325, 3: 203, 1: 313, 9: 68, 10: 46, 11: 40, 13: 45, 14: 54, 15: 59, 19: 56, 20: 45, 18: 56, 16: 50, 12: 55, 21: 61, 88: 141, 89: 117, 86: 157, 90: 134, 95: 89, 87: 126, 93: 137, 98: 107, 99: 104, 100: 115, 101: 107, 105: 114, 91: 118, 94: 120, 84: 133, 92: 114, 96: 111, 97: 108, 104: 109, 111: 93, 102: 126, 115: 100, 117: 74, 106: 121, 107: 117, 110: 100, 113: 111, 114: 93, 108: 113, 109: 101, 103: 122, 124: 75, 127: 95, 128: 76, 121: 68, 119: 85, 122: 57, 116: 83, 112: 93, 118: 77, 134: 77, 137: 63, 152: 84, 161: 40, 156: 49, 158: 43, 160: 41, 168: 24, 162: 36, 171: 16, 180: 12, 187: 5, 189: 5, 192: 4, 199: 2, 208: 2, 217: 2, 218: 1, 197: 3, 186: 5, 198: 5, 174: 14, 157: 41, 148: 114, 149: 95, 142: 86, 138: 86, 131: 63, 130: 111, 126: 74, 125: 85, 147: 88, 155: 49, 159: 37, 179: 9, 184: 3, 182: 7, 185: 6, 181: 4, 173: 8, 172: 19, 164: 22, 163: 26, 153: 63, 154: 58, 144: 102, 145: 105, 143: 89, 136: 61, 132: 85, 120: 77, 129: 105, 133: 79, 135: 90, 141: 91, 151: 86, 177: 12, 176: 8, 190: 5, 201: 4, 215: 1, 220: 2, 234: 2, 247: 1, 257: 3, 259: 1, 226: 1, 191: 4, 166: 32, 150: 80, 167: 19, 178: 11, 216: 1, 212: 3, 228: 1, 246: 1, 263: 2, 267: 2, 261: 1, 250: 1, 244: 1, 229: 1, 230: 4, 202: 2, 170: 21, 165: 26, 146: 89, 123: 75, 140: 73, 169: 23, 188: 3, 207: 1, 225: 1, 245: 1, 253: 1, 275: 1, 271: 1, 284: 1, 307: 1, 305: 1, 302: 1, 313: 1, 327: 1, 330: 1, 315: 1, 286: 1, 241: 1, 211: 1, 139: 78, 204: 1, 175: 11, 194: 1, 183: 3} (Minimum: 1)
#   File 2: {18: 1, 258: 1, 744: 1, 808: 1, 1085: 1} (Minimum: 18)
#   File 3: {86: 35, 85: 7, 84: 5, 83: 4, 82: 5, 81: 4, 80: 6, 79: 4, 78: 4, 77: 2, 76: 5, 75: 4, 74: 5, 73: 4, 72: 5, 71: 4, 70: 4, 69: 5, 68: 6, 67: 3, 66: 5, 65: 4, 64: 5, 63: 4, 62: 4, 61: 4, 60: 5, 59: 5, 58: 3, 57: 4, 56: 4, 55: 6, 54: 5, 52: 5, 51: 5, 50: 4, 49: 5, 48: 4, 47: 3, 46: 5, 45: 5, 44: 3, 43: 4, 42: 5, 40: 6, 39: 4, 38: 3, 37: 5, 36: 5, 35: 5, 34: 3, 33: 5, 32: 4, 31: 5, 30: 5, 29: 5, 28: 4, 27: 6, 26: 6, 25: 6, 24: 5, 23: 6, 22: 6, 21: 6, 20: 6, 19: 8, 18: 6, 17: 9, 16: 7, 15: 10, 14: 8, 13: 9, 12: 10, 11: 11, 10: 13, 9: 13, 8: 18, 7: 21, 6: 22, 100: 14349, 96: 3, 53: 4, 5: 3, 4: 3, 3: 2, 2: 271, 99: 3, 98: 2, 97: 3, 95: 2, 94: 2, 93: 2, 92: 1, 91: 2, 90: 2, 89: 2, 88: 2, 87: 2, 41: 3} (Minimum: 2)
# Folder: 2023-11-02-11-47-11_tiksoja_ride_16_sfa_split_1
#   File 1: {9: 272, 7: 283, 6: 219, 8: 295, 11: 206, 12: 144, 13: 101, 14: 66, 16: 44, 15: 53, 10: 264, 5: 251, 4: 209, 17: 32, 18: 47, 19: 35, 20: 26, 21: 24, 22: 17, 23: 19, 24: 26, 25: 28, 26: 22, 27: 29, 30: 6, 29: 9, 31: 10, 28: 19, 34: 2, 33: 2, 32: 2, 3: 310, 2: 595, 1: 1221} (Minimum: 1)
#   File 2: {163: 1, 646: 1} (Minimum: 163)
#   File 3: {55: 2, 54: 4, 53: 2, 52: 2, 51: 3, 50: 2, 49: 2, 48: 3, 47: 2, 46: 3, 45: 2, 44: 2, 43: 3, 42: 2, 41: 3, 40: 3, 39: 2, 38: 3, 37: 2, 36: 3, 35: 3, 34: 3, 33: 3, 32: 4, 31: 2, 30: 3, 29: 4, 28: 3, 27: 4, 26: 4, 25: 4, 24: 4, 23: 4, 22: 4, 21: 5, 20: 4, 19: 5, 18: 5, 17: 5, 16: 6, 15: 5, 14: 6, 13: 5, 12: 7, 11: 7, 10: 8, 9: 9, 8: 11, 7: 16, 6: 20, 100: 7310, 99: 1, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 1, 92: 1, 91: 2, 90: 1, 89: 1, 88: 2, 87: 1, 86: 1, 85: 2, 84: 1, 83: 1, 82: 2, 81: 1, 80: 1, 79: 2, 78: 1, 77: 1, 76: 2, 75: 1, 74: 1, 73: 2, 72: 1, 71: 1, 70: 2, 69: 1, 68: 1, 67: 2, 66: 1, 65: 1, 64: 1, 63: 2, 62: 1, 61: 1, 60: 2, 59: 1, 58: 1, 57: 2, 56: 1} (Minimum: 6)
# Folder: 2023-11-02-12-00-24_tiksoja_ride_16_sfa_split_2
#   File 1: {1: 1261, 2: 663, 3: 559, 5: 462, 4: 490, 6: 346, 7: 207, 8: 176, 11: 133, 9: 197, 10: 145, 12: 116, 13: 118, 14: 124, 15: 141, 17: 145, 16: 144, 18: 170, 19: 171, 23: 88, 25: 71, 21: 143, 24: 69, 20: 155, 22: 114, 26: 84, 29: 62, 27: 69, 28: 76, 32: 82, 33: 53, 30: 76, 34: 25, 31: 81, 36: 10, 35: 26, 38: 5, 37: 4, 40: 3, 44: 1, 43: 1, 41: 4, 42: 1} (Minimum: 1)
#   File 2: {183: 1, 585: 1} (Minimum: 183)
#   File 3: {100: 8818, 99: 2, 98: 3, 96: 3, 95: 2, 93: 2, 92: 3, 91: 2, 89: 2, 88: 3, 87: 3, 85: 3, 84: 3, 83: 3, 81: 4, 80: 5, 79: 4, 78: 6, 76: 7, 75: 7, 74: 8, 73: 6, 71: 4, 70: 4, 69: 4, 68: 4, 67: 3, 66: 4, 64: 3, 63: 4, 62: 3, 61: 3, 60: 4, 59: 3, 58: 3, 57: 3, 56: 3, 55: 3, 54: 5, 53: 3, 52: 4, 51: 3, 50: 4, 49: 4, 48: 4, 47: 4, 46: 3, 45: 4, 44: 4, 43: 4, 42: 4, 41: 4, 40: 4, 39: 3, 38: 5, 37: 3, 36: 5, 35: 4, 34: 4, 33: 3, 32: 5, 31: 4, 30: 4, 29: 5, 28: 3, 27: 5, 26: 5, 25: 4, 24: 5, 23: 4, 22: 5, 21: 4, 20: 5, 19: 4, 18: 6, 17: 4, 16: 6, 15: 4, 14: 6, 13: 5, 12: 7, 11: 7, 10: 7, 9: 9, 8: 10, 7: 15, 6: 21, 97: 1, 94: 1, 90: 2, 86: 2, 82: 3, 77: 4, 72: 4, 65: 2} (Minimum: 6)
# Folder: 2023-11-02-12-44-53_tiksoja_ride_17_cluster_split_1
#   File 1: {102: 78, 98: 47, 100: 45, 110: 92, 115: 54, 112: 72, 119: 45, 117: 37, 113: 79, 111: 85, 104: 79, 108: 89, 107: 93, 109: 94, 106: 74, 101: 66, 99: 61, 103: 73, 105: 72, 94: 45, 93: 46, 88: 55, 89: 62, 91: 55, 86: 59, 84: 66, 87: 64, 76: 68, 74: 67, 73: 64, 70: 65, 65: 46, 66: 57, 61: 42, 58: 44, 62: 44, 57: 33, 64: 43, 67: 60, 68: 72, 71: 65, 56: 30, 60: 42, 75: 65, 77: 48, 83: 57, 81: 61, 82: 65, 85: 52, 80: 44, 95: 57, 96: 60, 97: 52, 114: 56, 116: 51, 118: 47, 120: 48, 122: 42, 126: 31, 128: 31, 124: 35, 125: 29, 127: 33, 121: 34, 123: 33, 130: 35, 129: 30, 137: 26, 142: 58, 141: 56, 145: 54, 143: 59, 139: 45, 132: 37, 131: 40, 133: 33, 136: 43, 135: 38, 144: 55, 146: 66, 157: 10, 155: 6, 151: 17, 147: 44, 153: 21, 162: 5, 163: 10, 156: 5, 158: 10, 164: 12, 160: 6, 161: 11, 174: 8, 176: 6, 172: 7, 166: 4, 171: 10, 180: 6, 179: 5, 183: 7, 191: 3, 194: 5, 188: 7, 187: 7, 186: 6, 189: 1, 197: 1, 193: 1, 206: 1, 195: 1, 184: 3, 178: 7, 181: 7, 185: 3, 177: 4, 175: 6, 173: 3, 170: 4, 168: 6, 150: 20, 149: 28, 140: 40, 138: 27, 148: 27, 134: 25, 90: 54, 92: 64, 79: 51, 78: 50, 69: 89, 63: 37, 59: 38, 51: 31, 72: 68, 54: 26, 53: 41, 50: 35, 49: 39, 46: 32, 44: 49, 45: 45, 47: 39, 41: 50, 42: 52, 48: 40, 38: 60, 34: 62, 33: 78, 35: 76, 30: 64, 32: 56, 36: 75, 31: 57, 39: 62, 29: 64, 28: 67, 37: 54, 43: 47, 40: 64, 27: 47, 24: 50, 25: 46, 23: 44, 21: 28, 26: 58, 22: 37, 18: 10, 20: 34, 19: 18, 17: 8, 16: 9, 15: 7, 52: 21, 55: 29, 152: 17, 165: 12, 154: 14, 167: 5, 159: 6, 169: 6, 13: 3, 8: 3, 5: 10, 4: 12, 2: 99, 1: 80, 3: 29, 6: 5, 7: 2, 11: 6, 14: 6, 182: 4} (Minimum: 1)
#   File 2: {197: 1, 667: 1} (Minimum: 197)
#   File 3: {94: 2, 93: 2, 92: 2, 91: 2, 90: 3, 89: 1, 88: 2, 87: 2, 86: 3, 85: 2, 84: 2, 83: 2, 82: 3, 81: 2, 80: 2, 79: 2, 78: 2, 77: 3, 76: 2, 75: 1, 74: 3, 73: 2, 72: 2, 71: 2, 70: 3, 69: 2, 68: 2, 67: 2, 66: 3, 65: 2, 64: 2, 63: 3, 62: 2, 61: 2, 60: 2, 59: 2, 58: 2, 57: 2, 56: 3, 55: 2, 54: 2, 53: 2, 52: 2, 51: 3, 50: 2, 49: 2, 48: 3, 47: 2, 46: 2, 45: 4, 44: 1, 43: 3, 42: 2, 41: 3, 40: 2, 39: 2, 38: 3, 37: 3, 36: 3, 35: 2, 34: 3, 33: 3, 32: 2, 31: 4, 30: 3, 29: 2, 28: 4, 27: 4, 26: 3, 25: 4, 24: 3, 23: 4, 22: 4, 21: 5, 20: 4, 19: 5, 18: 5, 17: 5, 16: 6, 15: 6, 14: 6, 13: 6, 12: 8, 11: 8, 10: 9, 9: 11, 8: 15, 7: 20, 6: 24, 100: 6761, 99: 1, 98: 1, 97: 1, 96: 1, 95: 1} (Minimum: 6)
# Folder: 2023-11-02-12-58-32_tiksoja_ride_17_cluster_split_2
#   File 1: {72: 159, 73: 150, 71: 166, 70: 139, 68: 128, 69: 153, 74: 123, 75: 111, 77: 90, 79: 97, 81: 93, 78: 96, 76: 92, 80: 77, 65: 77, 67: 83, 66: 77, 82: 97, 83: 98, 84: 82, 85: 93, 87: 110, 89: 105, 86: 77, 63: 74, 60: 52, 61: 54, 64: 57, 62: 64, 88: 93, 59: 44, 94: 107, 99: 94, 100: 86, 91: 99, 57: 48, 54: 55, 51: 49, 53: 46, 46: 31, 45: 37, 52: 45, 47: 29, 44: 41, 49: 30, 50: 34, 43: 33, 41: 28, 40: 42, 39: 27, 38: 36, 36: 34, 34: 26, 31: 53, 27: 47, 21: 25, 22: 28, 20: 25, 26: 40, 35: 31, 42: 42, 58: 46, 55: 55, 93: 91, 95: 86, 90: 94, 92: 74, 56: 27, 48: 38, 96: 83, 104: 86, 101: 100, 98: 100, 102: 82, 108: 79, 109: 68, 103: 81, 106: 76, 107: 81, 110: 85, 114: 80, 119: 74, 122: 75, 116: 89, 120: 85, 123: 93, 124: 70, 126: 58, 131: 62, 127: 68, 128: 68, 135: 94, 134: 58, 132: 57, 130: 70, 129: 73, 125: 59, 136: 87, 138: 82, 140: 109, 144: 100, 118: 90, 117: 100, 147: 50, 152: 38, 156: 22, 160: 14, 164: 17, 169: 8, 162: 12, 163: 14, 167: 8, 157: 19, 166: 10, 171: 3, 174: 7, 183: 6, 181: 5, 179: 4, 176: 8, 177: 6, 182: 3, 170: 6, 149: 54, 141: 93, 133: 66, 142: 96, 137: 92, 139: 74, 121: 89, 115: 74, 111: 61, 113: 74, 143: 100, 151: 45, 145: 90, 155: 23, 158: 17, 153: 37, 148: 53, 146: 58, 168: 8, 172: 3, 161: 17, 150: 53, 159: 19, 154: 24, 112: 77, 105: 67, 97: 73, 37: 33, 30: 44, 28: 55, 33: 43, 25: 38, 24: 36, 23: 34, 19: 12, 17: 11, 15: 3, 11: 4, 10: 1, 9: 7, 12: 4, 13: 4, 5: 15, 3: 27, 4: 31, 6: 8, 7: 6, 2: 40, 1: 188, 8: 1, 29: 45, 32: 40, 165: 12, 18: 7, 16: 6, 14: 1, 184: 4, 195: 2, 185: 5, 175: 7, 188: 1, 187: 1, 178: 4, 180: 5, 190: 1, 196: 1, 202: 1, 189: 3, 194: 1, 193: 1, 191: 1, 186: 1, 173: 5} (Minimum: 1)
#   File 2: {118: 1, 741: 1} (Minimum: 118)
#   File 3: {100: 9096, 99: 2, 98: 3, 97: 2, 96: 3, 95: 2, 94: 4, 93: 2, 92: 3, 91: 3, 90: 3, 89: 3, 88: 3, 87: 3, 86: 3, 85: 4, 84: 5, 83: 4, 82: 3, 81: 6, 80: 5, 79: 6, 78: 5, 77: 7, 76: 10, 75: 13, 74: 105, 73: 9, 72: 5, 71: 6, 70: 4, 69: 5, 68: 4, 67: 5, 66: 3, 65: 4, 64: 4, 63: 4, 62: 3, 61: 4, 60: 4, 59: 4, 58: 4, 57: 4, 56: 3, 55: 4, 54: 5, 53: 5, 52: 3, 51: 5, 50: 4, 49: 5, 48: 5, 47: 6, 46: 5, 45: 5, 44: 5, 43: 5, 42: 5, 41: 4, 40: 5, 39: 6, 38: 4, 37: 5, 36: 5, 35: 5, 34: 4, 33: 4, 32: 5, 31: 4, 30: 5, 29: 4, 28: 4, 27: 4, 26: 5, 25: 5, 24: 6, 23: 5, 22: 6, 21: 4, 20: 4, 19: 5, 18: 5, 17: 5, 16: 4, 15: 5, 14: 6, 13: 5, 12: 6, 11: 6, 10: 7, 9: 7, 8: 9, 7: 12, 6: 16} (Minimum: 6)
# Folder: 2023-11-03-09-57-03_tiksoja_ride_18_sfa_split_1
#   File 1: {37: 5, 38: 5, 41: 3, 42: 1, 39: 2, 40: 3, 35: 3, 34: 3, 32: 6, 30: 23, 29: 34, 26: 68, 25: 85, 28: 49, 27: 56, 23: 131, 21: 159, 22: 162, 20: 175, 19: 153, 17: 90, 15: 68, 14: 69, 13: 67, 18: 127, 16: 57, 24: 113, 33: 2, 31: 14, 12: 67, 11: 77, 10: 79, 8: 132, 7: 173, 9: 124, 6: 218, 5: 262, 4: 344, 3: 672, 2: 1188, 1: 1900} (Minimum: 1)
#   File 2: {83: 1, 1228: 1} (Minimum: 83)
#   File 3: {58: 2, 57: 3, 56: 3, 55: 3, 54: 3, 53: 4, 52: 4, 51: 3, 50: 3, 49: 4, 48: 4, 47: 4, 46: 3, 45: 3, 44: 5, 43: 3, 42: 4, 41: 4, 40: 4, 39: 4, 38: 4, 37: 4, 36: 5, 35: 3, 34: 5, 33: 4, 32: 4, 31: 4, 30: 5, 29: 5, 28: 3, 27: 5, 26: 5, 25: 5, 24: 4, 23: 5, 22: 5, 21: 4, 20: 5, 19: 5, 18: 6, 17: 4, 16: 6, 15: 6, 14: 4, 13: 7, 12: 6, 11: 7, 10: 7, 9: 9, 8: 10, 7: 15, 6: 21, 100: 13674, 99: 1, 98: 1, 97: 1, 95: 1, 94: 1, 92: 1, 91: 1, 90: 1, 88: 1, 87: 1, 86: 1, 85: 1, 83: 1, 82: 1, 80: 1, 79: 1, 78: 1, 77: 1, 76: 1, 75: 1, 73: 1, 72: 1, 71: 1, 70: 1, 68: 1, 67: 1, 66: 1, 65: 1, 64: 1, 63: 1, 62: 1, 61: 1, 60: 1, 59: 1, 5: 1} (Minimum: 5)
# Folder: 2023-11-03-10-21-22_tiksoja_ride_18_sfa_split_2
#   File 1: {2: 973, 1: 1722, 3: 632, 4: 480, 5: 417, 6: 371, 8: 228, 9: 190, 11: 194, 10: 213, 7: 283, 12: 130, 13: 128, 15: 120, 14: 110, 17: 100, 19: 96, 16: 88, 18: 78, 20: 93, 21: 106, 25: 106, 23: 112, 22: 122, 24: 91, 26: 122, 27: 102, 28: 126, 29: 108, 33: 65, 30: 98, 31: 85, 34: 48, 32: 84, 35: 44, 37: 8, 41: 5, 45: 1, 44: 1, 36: 26, 38: 14, 39: 11, 40: 4, 42: 1} (Minimum: 1)
#   File 2: {1309: 1} (Minimum: 1309)
#   File 3: {100: 14640, 99: 2, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 1, 92: 2, 91: 2, 90: 1, 89: 2, 88: 2, 87: 2, 86: 3, 85: 2, 84: 3, 83: 3, 82: 4, 81: 3, 80: 3, 79: 3, 78: 3, 77: 3, 76: 3, 75: 3, 74: 3, 73: 2, 72: 3, 71: 2, 70: 3, 69: 3, 68: 2, 67: 2, 66: 3, 65: 2, 64: 3, 63: 2, 62: 2, 61: 3, 60: 2, 59: 2, 58: 2, 57: 3, 56: 2, 55: 2, 54: 3, 53: 2, 52: 2, 51: 2, 50: 3, 49: 2, 48: 3, 47: 2, 46: 2, 45: 3, 44: 2, 43: 2, 42: 3, 41: 3, 40: 2, 39: 3, 38: 2, 37: 3, 36: 3, 35: 2, 34: 2, 33: 3, 32: 2, 31: 3, 30: 2, 29: 3, 28: 3, 27: 2, 26: 3, 25: 2, 24: 3, 23: 2, 22: 3, 21: 3, 20: 2, 19: 3, 18: 2, 17: 3, 16: 2, 15: 3, 14: 2, 13: 3, 12: 2, 11: 3, 10: 3, 9: 4, 8: 4, 7: 6, 6: 9} (Minimum: 6)
# Folder: 2023-11-03-10-59-56_tiksoja_ride_19_cluster_split_1
#   File 1: {109: 62, 115: 68, 119: 49, 117: 45, 118: 53, 112: 58, 108: 77, 111: 55, 116: 61, 114: 53, 102: 52, 103: 59, 120: 44, 125: 52, 121: 37, 122: 53, 130: 41, 127: 34, 126: 39, 132: 69, 131: 53, 124: 45, 113: 63, 106: 63, 104: 60, 110: 48, 101: 66, 99: 60, 98: 70, 97: 82, 92: 74, 88: 76, 81: 77, 90: 87, 93: 88, 94: 72, 100: 64, 105: 77, 91: 71, 85: 80, 82: 61, 89: 102, 86: 87, 77: 75, 78: 58, 83: 69, 79: 79, 74: 70, 75: 42, 80: 74, 87: 68, 95: 63, 96: 70, 84: 65, 72: 65, 107: 74, 123: 53, 128: 38, 76: 57, 73: 54, 71: 60, 69: 56, 68: 48, 70: 56, 67: 49, 64: 64, 57: 75, 60: 76, 61: 82, 58: 70, 62: 73, 65: 71, 63: 90, 137: 48, 139: 56, 140: 51, 148: 31, 145: 36, 150: 22, 146: 30, 135: 46, 143: 36, 138: 61, 136: 53, 156: 20, 153: 21, 157: 15, 151: 29, 155: 15, 152: 23, 158: 16, 160: 22, 154: 26, 144: 37, 133: 40, 141: 45, 142: 44, 165: 9, 166: 12, 168: 9, 161: 9, 147: 20, 134: 49, 129: 44, 149: 30, 66: 36, 56: 63, 53: 39, 52: 37, 51: 44, 55: 50, 162: 10, 164: 11, 170: 6, 163: 9, 169: 10, 174: 3, 173: 5, 171: 2, 167: 5, 177: 3, 180: 3, 179: 3, 178: 3, 181: 3, 175: 6, 189: 1, 190: 1, 185: 4, 182: 3, 183: 3, 186: 1, 188: 2, 187: 1, 172: 3, 59: 67, 159: 9, 49: 35, 50: 25, 45: 33, 46: 26, 48: 28, 43: 39, 39: 70, 41: 58, 40: 72, 38: 100, 34: 122, 36: 122, 37: 99, 33: 99, 32: 81, 30: 85, 31: 81, 42: 34, 44: 36, 47: 31, 54: 45, 35: 129, 27: 56, 25: 39, 24: 30, 28: 60, 26: 38, 22: 25, 23: 28, 29: 60, 21: 23, 18: 6, 20: 12, 19: 10, 16: 4, 15: 4, 14: 4, 8: 4, 4: 11, 3: 30, 1: 87, 2: 88, 5: 7, 6: 1, 7: 4, 9: 4, 12: 2, 10: 3, 13: 5, 11: 1, 17: 1} (Minimum: 1)
#   File 2: {240: 1, 138: 1, 763: 1} (Minimum: 138)
#   File 3: {54: 4, 53: 5, 52: 3, 51: 4, 50: 4, 49: 3, 48: 3, 47: 4, 46: 3, 45: 3, 44: 5, 43: 3, 42: 4, 41: 3, 40: 4, 39: 4, 38: 3, 37: 4, 36: 3, 35: 5, 34: 4, 33: 3, 32: 4, 31: 4, 30: 3, 29: 5, 28: 5, 27: 4, 26: 4, 25: 5, 24: 4, 23: 4, 22: 6, 21: 3, 20: 5, 19: 5, 18: 4, 17: 6, 16: 4, 15: 4, 14: 5, 13: 5, 12: 5, 11: 6, 10: 6, 9: 7, 8: 7, 7: 16, 6: 20, 100: 7856, 99: 1, 98: 1, 97: 2, 96: 1, 95: 1, 94: 2, 93: 1, 92: 1, 91: 2, 90: 1, 89: 1, 88: 1, 87: 2, 86: 1, 85: 1, 84: 2, 83: 1, 82: 1, 81: 2, 80: 1, 79: 1, 78: 1, 77: 2, 76: 1, 75: 2, 74: 1, 73: 1, 72: 1, 71: 2, 70: 1, 69: 1, 68: 1, 67: 2, 66: 2, 64: 2, 63: 1, 62: 2, 61: 1, 60: 1, 59: 2, 58: 1, 57: 1, 56: 2, 55: 1} (Minimum: 6)
# Folder: 2023-11-03-11-14-53_tiksoja_ride_19_cluster_split_2
#   File 1: {139: 130, 137: 152, 138: 145, 132: 109, 135: 125, 140: 125, 133: 123, 143: 104, 134: 152, 136: 150, 144: 101, 141: 105, 145: 79, 131: 109, 149: 74, 129: 92, 126: 67, 146: 90, 150: 60, 142: 112, 151: 67, 148: 66, 147: 74, 152: 56, 154: 42, 153: 47, 128: 69, 130: 75, 127: 68, 155: 41, 125: 64, 122: 55, 124: 56, 123: 71, 119: 69, 156: 42, 162: 52, 170: 59, 164: 51, 167: 55, 161: 47, 158: 43, 159: 41, 160: 44, 112: 89, 121: 75, 118: 66, 165: 46, 171: 50, 166: 53, 168: 37, 157: 42, 113: 87, 115: 67, 106: 109, 110: 106, 111: 89, 103: 166, 109: 108, 107: 134, 104: 147, 102: 154, 91: 75, 85: 101, 93: 86, 78: 67, 77: 72, 88: 79, 81: 70, 80: 70, 82: 67, 83: 76, 90: 76, 86: 70, 94: 89, 87: 83, 89: 85, 97: 93, 95: 103, 99: 121, 116: 67, 120: 63, 96: 105, 92: 75, 100: 141, 79: 70, 76: 84, 75: 65, 72: 73, 70: 61, 63: 46, 67: 44, 84: 94, 74: 78, 69: 52, 68: 52, 98: 107, 64: 52, 73: 84, 71: 65, 65: 50, 59: 52, 58: 43, 62: 58, 53: 33, 49: 41, 55: 37, 54: 29, 44: 34, 46: 31, 45: 27, 47: 32, 41: 35, 40: 32, 48: 36, 50: 29, 57: 37, 60: 56, 61: 45, 66: 51, 52: 36, 51: 25, 43: 25, 42: 21, 39: 34, 35: 51, 34: 57, 31: 46, 29: 49, 26: 34, 25: 50, 24: 39, 20: 10, 28: 39, 36: 37, 37: 42, 27: 51, 30: 56, 32: 53, 33: 49, 21: 17, 19: 12, 16: 3, 13: 4, 14: 2, 15: 2, 12: 3, 10: 5, 11: 2, 9: 4, 8: 5, 6: 1, 3: 17, 2: 63, 4: 32, 5: 12, 1: 146, 7: 3, 22: 29, 23: 24, 56: 30, 38: 25, 18: 6, 17: 3, 108: 108, 114: 66, 105: 140, 117: 62, 101: 142, 163: 43, 173: 47, 176: 44, 175: 43, 179: 34, 177: 42, 172: 57, 169: 43, 186: 10, 184: 20, 187: 5, 190: 6, 188: 2, 182: 9, 181: 18, 178: 31, 174: 42, 185: 12, 192: 3, 193: 6, 200: 4, 208: 1, 205: 1, 201: 2, 191: 6, 197: 2, 198: 3, 195: 2, 199: 3, 194: 4, 196: 2, 189: 3, 180: 19, 183: 13} (Minimum: 1)
#   File 2: {631: 1, 908: 1} (Minimum: 631)
#   File 3: {100: 10262, 99: 4, 98: 4, 97: 5, 96: 4, 95: 5, 94: 6, 93: 6, 92: 5, 91: 6, 90: 6, 89: 9, 88: 67, 87: 15, 86: 8, 85: 6, 84: 8, 83: 7, 82: 7, 81: 5, 80: 6, 79: 5, 78: 4, 77: 5, 76: 4, 75: 4, 74: 4, 73: 4, 72: 4, 71: 3, 70: 5, 69: 3, 68: 3, 67: 4, 66: 3, 65: 4, 64: 3, 63: 4, 62: 4, 61: 3, 60: 4, 59: 3, 58: 3, 57: 4, 56: 4, 55: 4, 54: 4, 53: 4, 51: 4, 50: 4, 49: 4, 48: 4, 47: 4, 46: 3, 45: 4, 44: 3, 43: 4, 42: 3, 41: 3, 40: 4, 39: 4, 38: 4, 37: 3, 36: 4, 35: 4, 34: 3, 33: 4, 32: 3, 31: 4, 30: 5, 29: 4, 28: 3, 27: 5, 26: 3, 25: 4, 24: 5, 23: 4, 22: 4, 21: 4, 20: 5, 19: 4, 18: 4, 17: 5, 16: 5, 15: 4, 14: 6, 13: 4, 12: 5, 11: 3, 10: 5, 9: 5, 8: 7, 7: 10, 6: 14, 5: 1, 4: 2, 3: 1, 2: 82, 52: 3} (Minimum: 2)
# Folder: 2023-11-03-13-42-01_tiksoja_ride_20_sfa_split_1
#   File 1: {3: 852, 4: 623, 5: 414, 2: 915, 1: 1087, 6: 251, 7: 231, 8: 226, 9: 152, 10: 110, 11: 85, 12: 91, 13: 97, 14: 123, 15: 71, 16: 78, 17: 62, 19: 16, 18: 39, 20: 5, 21: 5, 24: 1, 22: 1} (Minimum: 1)
#   File 2: {223: 1, 635: 1} (Minimum: 223)
#   File 3: {88: 2, 87: 2, 86: 2, 85: 2, 84: 3, 83: 2, 82: 2, 81: 2, 80: 3, 79: 2, 78: 2, 77: 2, 76: 2, 75: 1, 74: 3, 73: 2, 72: 2, 71: 2, 70: 3, 69: 2, 68: 2, 67: 2, 66: 2, 65: 3, 64: 2, 63: 2, 62: 2, 61: 2, 60: 2, 59: 2, 58: 2, 57: 2, 56: 2, 55: 3, 54: 2, 53: 2, 52: 2, 51: 2, 50: 2, 49: 3, 48: 2, 47: 2, 46: 2, 45: 2, 44: 4, 43: 2, 42: 2, 41: 2, 40: 2, 39: 4, 38: 2, 37: 2, 36: 2, 35: 4, 34: 2, 33: 3, 32: 2, 31: 4, 30: 3, 29: 2, 28: 4, 27: 3, 26: 3, 25: 4, 24: 3, 23: 4, 22: 3, 21: 4, 20: 4, 19: 5, 18: 4, 17: 5, 16: 6, 15: 5, 14: 7, 13: 6, 12: 8, 11: 8, 10: 10, 9: 11, 8: 14, 7: 21, 6: 24, 100: 7563, 99: 1, 98: 1, 97: 1, 96: 1, 95: 1, 94: 1, 93: 1, 92: 1, 91: 1, 90: 1} (Minimum: 6)
# Folder: 2023-11-03-13-56-06_tiksoja_ride_20_sfa_split_2
#   File 1: {1: 1111, 4: 503, 5: 376, 6: 336, 3: 547, 2: 821, 9: 178, 8: 258, 7: 261, 10: 180, 11: 196, 12: 180, 14: 214, 17: 223, 15: 210, 13: 171, 16: 210, 18: 158, 20: 164, 19: 139, 22: 120, 23: 108, 21: 131, 24: 126, 26: 93, 25: 109, 28: 81, 29: 80, 27: 100, 30: 88, 32: 97, 31: 92, 34: 97, 35: 85, 33: 100, 37: 45, 36: 73, 42: 1, 41: 4, 40: 7, 38: 24, 39: 13} (Minimum: 1)
#   File 2: {118: 1, 741: 1} (Minimum: 118)
#   File 3: {100: 10308, 99: 4, 98: 3, 97: 3, 96: 2, 95: 4, 94: 2, 93: 3, 92: 3, 91: 4, 90: 3, 89: 2, 88: 4, 87: 3, 86: 3, 85: 3, 84: 3, 83: 3, 82: 4, 81: 3, 80: 3, 79: 4, 78: 2, 77: 3, 76: 4, 75: 4, 74: 3, 73: 3, 72: 4, 71: 3, 70: 4, 69: 3, 68: 4, 67: 4, 66: 4, 65: 4, 64: 4, 63: 4, 62: 3, 61: 4, 60: 4, 59: 4, 58: 4, 57: 4, 56: 5, 55: 4, 54: 5, 53: 4, 52: 4, 51: 5, 50: 4, 49: 5, 48: 4, 47: 5, 46: 4, 45: 5, 44: 5, 43: 5, 42: 5, 41: 4, 40: 5, 39: 4, 38: 4, 37: 5, 36: 5, 35: 4, 34: 5, 33: 5, 32: 4, 31: 5, 30: 5, 29: 5, 28: 4, 27: 5, 26: 5, 25: 4, 24: 5, 23: 5, 22: 4, 21: 5, 20: 4, 19: 5, 18: 5, 17: 4, 16: 6, 15: 5, 14: 4, 13: 6, 12: 5, 11: 6, 10: 7, 9: 7, 8: 8, 7: 11, 6: 17} (Minimum: 6)
#
# Overall Minimums Across All Folders:
#   File 1: 1
#   File 2: 2
#   File 3: 2

# %%
# Folder where the processed CSVs are stored
processed_folder = "F:\\Processed_CSVs"

# Helper function to rename columns matching the pattern {feature}_{i}
def rename_columns(df, prefix):
    def rename_column(col):
        parts = col.split('_')  # Split column name by underscores
        if parts[-1].isdigit():  # Check if the last part is a digit
            return f"{prefix}_{col}"  # Rename column with the prefix
        return col

    return df.rename(columns=rename_column)

# Helper function to 'throw out' rows where all columns starting with a prefix are NaN - meaning if there are no detected objects or waypoints for a timestamp, we can remove that row
def filter_by_last_filled(df, prefix):
    # Identify all columns that start with the prefix and end with a digit
    pattern_columns = [col for col in df.columns if col.startswith(prefix) and col.split('_')[-1].isdigit()]

    if not pattern_columns:
        raise ValueError(f"No columns starting with '{prefix}' and ending with a digit found.")

    def has_valid_column(row):
        # Check if any of the identified columns are filled (not NaN) in this row
        return row[pattern_columns].notna().any()

    # Use the filter function to retain rows where at least one relevant column is filled
    valid_mask = df.apply(has_valid_column, axis=1)
    return df[valid_mask]


# Helper function to truncate columns to a specific limit
def truncate_columns(df, prefix, limit):
    def should_keep_column(col):
        # Check if the column starts with the prefix and ends with a digit
        if col.startswith(prefix) and col.split("_")[-1].isdigit():
            # Keep the column if the last digit is less than or equal to the limit
            return int(col.split("_")[-1]) <= limit
        # Keep columns that do not end with a digit
        return True

    # Filter columns based on the `should_keep_column` function
    columns_to_keep = [col for col in df.columns if should_keep_column(col)]
    return df[columns_to_keep]


# Initialize a global mapping for all labels
global_label_mapping = {}

def categorize_labels(df):
    global global_label_mapping  # Access the global mapping
    
    for col in df.columns:
        # Check if "label" appears between underscores in the column name
        if re.search(r"_label_", col):
            # Extract unique values from the column
            unique_values = df[col].dropna().unique()
            
            # Add new labels to the global mapping if not already present
            for value in unique_values:
                if value not in global_label_mapping:
                    global_label_mapping[value] = len(global_label_mapping)

            # Map the column values to consistent codes using the global mapping
            df[col] = df[col].map(global_label_mapping).fillna(-1).astype(int)
    
    return df



# Main processing logic
# Iterate over all folders in the processed folder and all csv files within each folder
for folder_name in os.listdir(processed_folder):
    folder_path = os.path.join(processed_folder, folder_name)
    if os.path.isdir(folder_path):
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if not file_name.endswith(".csv"):
                continue

            try:
                # Read the CSV file
                df = pd.read_csv(file_path, low_memory=False)

                if file_name == "processed_detection-final_objects.csv":
                    df = rename_columns(df, "objects") # Rename the columns with the prefix "objects"
                    df = filter_by_last_filled(df, "objects") # Filter out rows where all object columns are NaN
                    df = truncate_columns(df, "objects", 10) # Truncate the object columns to a maximum of 10
                    df = categorize_labels(df) # Categorize the labels and map them to consistent codes
                    df.fillna(-999, inplace=True) # Fill NaN values with a specific value
                
                elif file_name == "processed_planning-global_path.csv":
                    df = rename_columns(df, "global") # Rename the columns with the prefix "global"
                    df = filter_by_last_filled(df, "global") # Filter out rows where all global columns are NaN
                    df = truncate_columns(df, "global", 10) # Truncate the global columns to a maximum of 10
                    df.fillna(-999, inplace=True) # Fill NaN values with a specific value

                elif file_name == "processed_planning-local_path.csv":
                    df = rename_columns(df, "local") # Rename the columns with the prefix "local"
                    df = filter_by_last_filled(df, "local") # Filter out rows where all local columns are NaN
                    df = truncate_columns(df, "local", 10) # Truncate the local columns to a maximum of 10
                    df.fillna(-999, inplace=True) # Fill NaN values with a specific value
                
                # Save the processed file back to the same location (or modify as needed)
                df.to_csv(file_path, index=False)
                print(f"Processed file: {file_path}")

            except Exception as e:
                print(f"Error processing file {file_path}: {e}")
# Out:
# F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\2023-10-16-10-14-49_tiksoja_ride_02_sfa_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\2023-10-16-10-14-49_tiksoja_ride_02_sfa_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\2023-10-16-10-14-49_tiksoja_ride_02_sfa_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-14-49_tiksoja_ride_02_sfa\2023-10-16-10-14-49_tiksoja_ride_02_sfa_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_5.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_5.csv
# F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_6.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-30-17_tiksoja_ride_03_cluster\2023-10-16-10-30-17_tiksoja_ride_03_cluster_with_disengagements_disengagement_6.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_5.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_5.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_6.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_6.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_7.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_7.csv
# F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_8.csv
# Processed file: F:\Processed_CSVs\2023-10-16-10-50-24_tiksoja_ride_04_sfa\2023-10-16-10-50-24_tiksoja_ride_04_sfa_with_disengagements_disengagement_8.csv
# F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-16-13-47-19_tiksoja_ride_05_cluster\2023-10-16-13-47-19_tiksoja_ride_05_cluster_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_5.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_5.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_6.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_6.csv
# F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_7.csv
# Processed file: F:\Processed_CSVs\2023-10-16-15-23-20_tiksoja_ride_08_cluster\2023-10-16-15-23-20_tiksoja_ride_08_cluster_with_disengagements_disengagement_7.csv
# F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2\2023-10-30-09-55-20_tiksoja_ride_09_sfa_split_2_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1\2023-10-30-10-21-51_tiksoja_ride_10_cluster_split_1_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_5.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_5.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_6.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_6.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_7.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_7.csv
# F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_8.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2\2023-10-30-10-34-58_tiksoja_ride_10_cluster_split_2_with_disengagements_disengagement_8.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_5.csv
# Processed file: F:\Processed_CSVs\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1\2023-10-30-10-53-17_tiksoja_ride_11_cluster_split_1_with_disengagements_disengagement_5.csv
# F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2\2023-10-30-11-07-11_tiksoja_ride_11_cluster_split_2_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\processed_detection-final_objects.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\processed_detection-final_objects.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\processed_planning-global_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\processed_planning-global_path.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\processed_planning-local_path.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\processed_planning-local_path.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_1.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_1.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_2.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_2.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_3.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_3.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_4.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_4.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_5.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_5.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_6.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_6.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_7.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_7.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_8.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_8.csv
# F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_9.csv
# Processed file: F:\Processed_CSVs\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1\2023-10-30-14-28-38_tiksoja_ride_12_sfa_split_1_with_disengagements_disengagement_9.csv
# F:\Processed_CSVs\2023-10-30-15-04-36_tiksoja_ride_13_cluster_split_1\processed_detection-final_objects.csv

# %%
print("Global Category Mapping:", global_label_mapping)
# Out:
# Global Category Mapping: {'car': 0, 'truck': 1, 'pedestrian': 2, 'bus': 3, 'bicyclist': 4, 'on_road_obstacle': 5, 'trailer': 6, 'motorcyclist': 7, 'traffic_cone': 8, 'animal': 9, 'stroller': 10, 'unknown': 11}
